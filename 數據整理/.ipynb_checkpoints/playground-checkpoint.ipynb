# %%
import pandas as pd
pd.set_option("display.max_rows", 8)
pd.set_option("display.max_columns", None)
import tkinter as tk
from tkinter import filedialog

# %%
class TestArea():
    root = tk.Tk()
    root.withdraw()
    print("請選擇要開啟的檔案")
    file_path = filedialog.askopenfilename()
    DATA = pd.read_excel(file_path, None)
    sheet_dict = {}
    for k, v in enumerate(list(DATA.keys())):
        sheet_dict.setdefault(k+1, v)
    for k, v in sheet_dict.items():
        print(k, v)
    print("請選擇要開啟的活頁簿")
    slct_sheet = eval(input(""))    
    sheet_name = sheet_dict[slct_sheet]
    DATA = pd.read_excel(file_path, sheet_name = sheet_name)
    def __init__(self, name, age, data=DATA):
        self.name = name
        self.age = age
        self.data = data
        
    def antenna_preprocessing(self):
        return self.data[self.data["負責業務"].isin(["許凱智"])]
# Out:
# 請選擇要開啟的檔案
# 1 Dashboard
# 2 元件天線客戶貢獻度
# 3 各年份實績樞紐流動
# 4 20192020實績折線圖
# 5 2020累積實績固定
# 6 固定實績樞紐
# 7 2020預算固定表
# 8 2020預算流動
# 9 Amber週報用預算
# 10 全年預算by person
# 11 2020預算
# 12 客戶 年份樞紐
# 13 各類別圓餅圖
# 14 業務實績排名
# 15 各客戶成長率
# 16 Weekly report
# 17 週報更新用樞紐
# 18 Amber週報用格式
# 19 差異分析用樞紐
# 20 天線出貨量樞紐
# 21 元件出貨量直條圖
# 22 Cathy客戶樞紐
# 23 給二廠的Teltonika數據
# 24 每月15號左右給Wiley的圖表
# 25 固定天線當月實績
# 26 LF ODM
# 27 總實績表格for Amber
# 28 出貨明細
# 29 2021業績總表 (2) Mohan+Kai Edited
# 30 工作表3
# 31 Wurth開會報告用
# 32 分類命名表
# 33 工作表1
# 34 成長率byBG
# 35 2021預算固定表
# 36 2021預算流動
# 37 華新科By BU分析
# 38 2021預算總表
# 39 2021年實績預算達成率
# 請選擇要開啟的活頁簿
# 28

# %%
x = TestArea("Kai", 20)

# %%
x.antenna_preprocessing()
# Out:
#      Category      BG Subcategory      Group    狀態        銷售單號  銷售項次    月份  \
# 33       MCB1     EMC         NaN  TELTONIKA  01已出  WON19A0091     5   NaN
# 34       MIP2     EMC         NaN  TELTONIKA  01已出  WON19A0091    13   NaN
# 35       MHC1     EMC         NaN  TELTONIKA  01已出  WON19A0091    17   NaN
# 36       MCB1     EMC         NaN  TELTONIKA  01已出  WON19A0091    21   NaN
# ...       ...     ...         ...        ...   ...         ...   ...   ...
# 8279     DPA成      RF         NaN  TELTONIKA  12已出  YT220A0001    33  10.0
# 8280     DPA成      RF         NaN  TELTONIKA  12已出  YT220A0001    34  10.0
# 8285     MISC  Others         NaN  MT-SYSTEM  雜項訂單  SRO2090003     1   9.0
# 8286     MISC  Others         NaN      Zebra  雜項訂單  SRO20A0027     1  10.0
#
#            開單日期       預交日期  預交年份       預交月份       交期變更      客戶名稱 負責業務  \
# 33   2019-10-15 2020-01-20  2020    January 2019-12-18  TELTONIK  許凱智
# 34   2019-10-15 2020-01-20  2020    January 2019-12-18  TELTONIK  許凱智
# 35   2019-10-15 2020-01-20  2020    January 2019-12-18  TELTONIK  許凱智
# 36   2019-10-15 2020-01-20  2020    January 2019-12-18  TELTONIK  許凱智
# ...         ...        ...   ...        ...        ...       ...  ...
# 8279 2020-10-19 2020-12-17  2020   December 2020-12-11  TELTONIK  許凱智
# 8280 2020-10-19 2020-12-17  2020   December 2020-12-11  TELTONIK  許凱智
# 8285 2020-09-07 2020-09-23  2020  September        NaT  MT-Syste  許凱智
# 8286 2020-10-28 2020-11-19  2020   November        NaT     Zebra  許凱智
#
#          交貨方式                產品分類                           品名   幣別      數量  \
# 33        DHL  MCB1005-S series成品               MCB1005S300FBP  USD   10000
# 34        DHL    MIP2012 series成品                MIP20121R0MBE  USD  207000
# 35        DHL  MHC1608-S series成品               MHC1608S600QBP  USD  264000
# 36        DHL  MCB1608-S series成品               MCB1608S152HBP  USD   28000
# ...       ...                 ...                          ...  ...     ...
# 8279      DHL               DPA成品         RFDPA171300SBAB823J4  USD    3500
# 8280      DHL               DPA成品         RFDPA171300SBAB823J4  USD    1000
# 8285  NO SHIP                MISC       pintopinantennatooling  USD       1
# 8286      DHL                MISC  SamplecostforACA-1903-P2-GF  USD     303
#
#         已出數量  未出數         單價     匯率    本國幣別NTD                  客戶料號  \
# 33     10000    0     0.0012  28.81    345.720        MCB1005S300FBP
# 34    207000    0     0.0100  28.81  59636.700         MIP20121R0MBE
# 35    264000    0     0.0015  28.81  11408.760        MHC1608S600QBP
# 36     28000    0     0.0020  28.81   1613.360        MCB1608S152HBP
# ...      ...  ...        ...    ...        ...                   ...
# 8279    3500    0     0.7300  29.10  74350.500  RFDPA171300SBAB823J4
# 8280    1000    0     0.7300  29.10  21243.000  RFDPA171300SBAB823J4
# 8285       1    0  1307.9400  29.10  38061.054                   NaN
# 8286     303    0     1.0000  29.10   8817.300                   NaN
#
#           客戶希交日 Term           出通單號
# 33   2020-01-20  EXW     ZFN2010204
# 34   2020-01-20  EXW     ZFN2010204
# 35   2020-01-20  EXW     ZFN2010204
# 36   2020-01-20  EXW     ZFN2010204
# ...         ...  ...            ...
# 8279 2020-12-17  EXW  YT320C0034-33
# 8280 2020-12-17  EXW  YT320C0035-34
# 8285 2020-09-23  EXW   SRF2091246-1
# 8286 2020-11-19  EXW   SRF20B1019-1
#
# [3701 rows x 29 columns]
