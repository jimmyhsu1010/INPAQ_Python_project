# %%
import time
import pandas as pd
import tkinter as tk
from tkinter import filedialog
pd.set_option('display.max_rows', 10)
pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', lambda x: '%.0f' % x)

# %% [markdown]
# ## 使用Tkinter選取檔案

# %%
def get_file_path():
    root = tk.Tk()
    root.withdraw()
    file_path = filedialog.askdirectory() #取得檔案夾路徑
#     file_name = file_path.split('/')[-1].split('.')[0] #取得檔案名稱
    return file_path

# %%
def get_file_paths():
    root = tk.Tk()
    root.withdraw()
    file_paths = filedialog.askopenfilenames() #取得所有檔案路徑
#     file_name = file_path.split('/')[-1].split('.')[0] #取得檔案名稱
#     return file_path, file_name
    file_paths = list(file_paths)
    return file_paths

# %% [markdown]
# ## Function寫作

# %%
# data_list丟入取得所有檔案路徑的字典
def display(data_list):
    data_dict = {}
    for i in data_list:
        print(data_list.index(i)+1, i.split('/')[-1].split('.')[0])
        data_dict.setdefault(data_list.index(i)+1, i)
    return data_dict

# %%
# sltd_file丟入選擇的檔案編號
def file_info(sltd_file, y):
    file_path = y[sltd_file]
    file_name = y[sltd_file].split('/')[-1].split('.')[0] + '已修改.xlsx'
    return file_path, file_name

# %%
def change_name(data):
    if data in ['周彥宏', '楊婉芬']:
        return '許凱智'
    else:
        return data

# %% [markdown]
# ## 三廠資料處理Function

# %%
df = pd.read_excel(r"C:\Users\kaihsu\Desktop\業績總表\訂單出貨明細_axmr4301_2019.xlsx")

# %%
df.columns = df.columns.str.strip()

# %%
df['開單日期']
# Out:
# 0      2019-07-18
# 1      2019-08-21
# 2      2019-03-20
# 3      2019-06-28
# 4      2019-07-29
#           ...
# 3994   2019-11-22
# 3995   2019-12-02
# 3996   2019-12-20
# 3997   2019-12-20
# 3998   2019-11-28
# Name: 開單日期, Length: 3999, dtype: datetime64[ns]

# %%
df['開單日期'] = pd.to_datetime(df['開單日期'], yearfirst=True, unit='D')
df['預交日期'] = pd.to_datetime(df['預交日期'], yearfirst=True, unit='D')
df['客戶希交日'] = pd.to_datetime(df['客戶希交日'], yearfirst=True, errors='coerce', unit='D')
df['交期變更'] = pd.to_datetime(df['交期變更'], yearfirst=True, errors='coerce', unit='D')

# %%
keep_columns = ['狀態', '銷售單號', '月份', '開單日期', '預交日期', '交期變更', '客戶名稱', '負責業務', '交貨方式', '產品分類', '品名', '幣別', '數量', '單位',
                    '單價', '集團匯率(NTD)', '金額*集團匯率(NTD)', '客戶料號', '客戶希交日', 'Term']
df = df[keep_columns]
# columns_strip = ['狀態', '銷售單號', '客戶名稱', '負責業務', '交貨方式',
#                      '產品分類', '品名', '幣別', '單位', '客戶料號',
#                      'Term']
# df_strip = df[columns_strip]
# df_strip = df_strip.applymap(lambda x: x.strip())
# df = pd.concat([df_strip, df_keep], axis=1)

df_unit_change = df[df['單位'] == 'KPCS']
df_keep_unit = df[~(df['單位'] == 'KPCS')]

df_unit_change['數量'] = df_unit_change['數量'].map(lambda x: x * 1000)
df_unit_change['單價'] = df_unit_change['單價'].map(lambda x: x / 1000)
df_unit_change['單位'] = df_unit_change['單位'].str.replace('KPCS', 'PCS')

df = pd.concat([df_unit_change, df_keep_unit], axis=0)
# Out:
# <ipython-input-243-8f12f228551c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_unit_change['數量'] = df_unit_change['數量'].map(lambda x: x * 1000)
# <ipython-input-243-8f12f228551c>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_unit_change['單價'] = df_unit_change['單價'].map(lambda x: x / 1000)
# <ipython-input-243-8f12f228551c>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_unit_change['單位'] = df_unit_change['單位'].str.replace('KPCS', 'PCS')

# %%
append_dict = {0: 'Category', 1: 'BG', 2: 'Subcategory', 3: 'Group', 4: '預交年份', 5: '預交月份', }
for k, v in append_dict.items():
    df.insert(k, v, value=None)

df = df.drop('單位', axis=1)

columns = ['Category', 'BG', 'Subcategory', 'Group', '狀態', '銷售單號', '月份', '開單日期', '預交日期', '預交年份', '預交月份', '交期變更',
           '客戶名稱', '負責業務', '交貨方式', '產品分類', '品名', '幣別', '數量', '單價', '集團匯率(NTD)', '金額*集團匯率(NTD)', '客戶料號', '客戶希交日', 'Term']
result = df.reindex(columns=columns)

# %%
result['Category'] = result['產品分類'].str.strip().str[0:4]

# %%
result
# Out:
#      Category    BG Subcategory Group    狀態        銷售單號  月份       開單日期  \
# 0        SGX1  None        None  None  09已出  SON1970371   7 2019-07-18
# 1        SGX1  None        None  None  12已出  SON1980537   8 2019-08-21
# 2        SGX1  None        None  None  07已出  SON1930349   3 2019-03-20
# 3        SGX1  None        None  None  08已出  SON1960501   6 2019-06-28
# 4        SGX1  None        None  None  10已出  SON1970584   7 2019-07-29
# ...       ...   ...         ...   ...   ...         ...  ..        ...
# 3994     PPTC  None        None  None  11已出  WAN19B0011  11 2019-11-22
# 3995       代工  None        None  None  12已出  WAN19C0001  12 2019-12-02
# 3996       代工  None        None  None  12已出  WAN19C0003  12 2019-12-20
# 3997       代工  None        None  None  12已出  WAN19C0003  12 2019-12-20
# 3998     PPTC  None        None  None  12已出  WAN19B0020  11 2019-11-28
#
#            預交日期  預交年份  預交月份       交期變更   客戶名稱 負責業務      交貨方式         產品分類  \
# 0    2019-09-19  None  None 2019-08-22  EATON  沈思明  AIR-FWRD  SGX1206-4成品
# 1    2019-12-03  None  None 2019-10-09  EATON  沈思明  AIR-FWRD  SGX1206-4成品
# 2    2019-07-02  None  None 2019-05-03  EATON  沈思明  AIR-FWRD  SGX1206-4成品
# 3    2019-08-15  None  None 2019-08-06  EATON  沈思明  AIR-FWRD  SGX1206-4成品
# 4    2019-10-03  None  None 2019-09-11  EATON  沈思明  AIR-FWRD  SGX1206-4成品
# ...         ...   ...   ...        ...    ...  ...       ...          ...
# 3994 2019-11-22  None  None        NaT  LF.瑞侃  沈思明  BY TRUCK       PPTC成品
# 3995 2019-12-03  None  None        NaT   天灣電子  沈思明   EXPRESS           代工
# 3996 2019-12-20  None  None        NaT   天灣電子  沈思明   EXPRESS           代工
# 3997 2019-12-24  None  None        NaT   天灣電子  沈思明   EXPRESS           代工
# 3998 2019-12-09  None  None 2019-12-20  LF.瑞侃  沈思明  BY TRUCK       PPTC成品
#
#                          品名   幣別  數量   單價  集團匯率(NTD)  金額*集團匯率(NTD)  \
# 0       SurgX Array (ESD41)  USD 100   54         29        154998
# 1       SurgX Array (ESD41)  USD 100   54         29        154998
# 2       SurgX Array (ESD41)  USD 120   54         29        185997
# 3       SurgX Array (ESD41)  USD 100   54         29        154998
# 4       SurgX Array (ESD41)  USD 100   54         29        154998
# ...                     ...  ...  ..  ...        ...           ...
# 3994            PPTC Sample  CNY   4 2409          4         42202
# 3995       RR2268-000研磨--外觀  CNY 300   15          4         19708
# 3996       RR2268-000研磨--外觀  CNY 150   15          4          9854
# 3997       RR2268-000研磨--外觀  CNY 150   15          4          9854
# 3998  PSR29330-C-8064壓合後-外觀  CNY  58  725          4        183368
#
#                客戶料號      客戶希交日 Term
# 0     41206ESDA-TR1 2019-09-19  FCA
# 1     41206ESDA-TR1 2019-12-03  FCA
# 2     41206ESDA-TR1 2019-07-02  FCA
# 3     41206ESDA-TR1 2019-08-15  FCA
# 4     41206ESDA-TR1 2019-10-11  FCA
# ...             ...        ...  ...
# 3994              . 2019-11-22  CIP
# 3995     RR2268-000 2019-12-03  EXW
# 3996     RR2268-000 2019-12-20  EXW
# 3997     RR2268-000 2019-12-24  EXW
# 3998     RS4440-000 2019-12-09  CIP
#
# [3999 rows x 25 columns]

# %%
result['BG'] = result['Category'].map(bu_code)

# %%
result['Group'] = result.apply(lambda x: cus_code[x['客戶名稱']] if x['客戶名稱'] in cus_code.keys() else x['客戶名稱'], axis=1)

# %%
result['負責業務'] = result['負責業務'].map(lambda x: '許凱智' if x == '楊婉芬' or x == '周彥宏' else x)

# %%
result = result[result['負責業務'].isin(['鄭里緗', '許凱智', '墨漢雷迪'])]

# %%
result['預交年份'] = result['預交日期'].dt.year
result['預交月份'] = result['預交日期'].dt.month_name()

# %%
result.columns = ['Category', 'BG', 'Subcategory', 'Group', '狀態', '銷售單號', '月份', '開單日期',
       '預交日期', '預交年份', '預交月份', '交期變更', '客戶名稱', '負責業務', '交貨方式', '產品分類', '品名',
       '幣別', '數量', '單價', '匯率', '本國幣別NTD', '客戶料號', '客戶希交日', 'Term']

# %%
result['數量'] = result['數量'].astype(int)
result['本國幣別NTD'] = result['本國幣別NTD'].astype(int)

# %%
result
# Out:
#      Category  BG Subcategory      Group    狀態        銷售單號  月份       開單日期  \
# 13       ACA-  RF        None  MT-SYSTEM  01已出  SON18B0651  11 2018-11-29
# 71       ACA-  RF        None   Globalte  04已出  SAN1930093   3 2019-03-21
# 86       ACA-  RF        None  MT-SYSTEM  04已出  SON1930452   3 2019-03-19
# 137      ACA5  RF        None     Eteily  05已出  SON1950189   5 2019-05-10
# 138      ACA5  RF        None     Eteily  05已出  SON1950189   5 2019-05-10
# ...       ...  ..         ...        ...   ...         ...  ..        ...
# 1521     GSM成  RF        None   Univa Te  12未出  STN20C0008  12 2020-12-09
# 1522     GSM成  RF        None   Sancraft  01未出  STN20C0010  12 2020-12-14
# 1523     GSM成  RF        None   Sancraft  01未出  STN20C0010  12 2020-12-14
# 1524     GSM成  RF        None   Sancraft  01未出  STN20C0010  12 2020-12-14
# 1525     Chip  RF        None       M.S.  12未出  YT220C0001  12 2020-12-03
#
#            預交日期  預交年份      預交月份 交期變更      客戶名稱  負責業務      交貨方式  \
# 13   2019-01-10  2019   January  NaT  MT-Syste   許凱智       DHL
# 71   2019-04-02  2019     April  NaT  Globalte  墨漢雷迪       DHL
# 86   2019-04-03  2019     April  NaT  MT-Syste   許凱智       DHL
# 137  2019-05-29  2019       May  NaT    Eteily  墨漢雷迪       DHL
# 138  2019-05-29  2019       May  NaT    Eteily  墨漢雷迪       DHL
# ...         ...   ...       ...  ...       ...   ...       ...
# 1521 2020-12-09  2020  December  NaT  Univa Te  墨漢雷迪  AIR-FWRD
# 1522 2021-01-04  2021   January  NaT  Sancraft  墨漢雷迪  AIR-FWRD
# 1523 2021-01-04  2021   January  NaT  Sancraft  墨漢雷迪  AIR-FWRD
# 1524 2021-01-04  2021   January  NaT  Sancraft  墨漢雷迪  AIR-FWRD
# 1525 2020-12-04  2020  December  NaT      M.S.  墨漢雷迪  AIR-FWRD
#
#                   產品分類                        品名   幣別      數量  單價  匯率  \
# 13    ACA-5036-A2-CC成品  ACM4-5036-A1-CC-S Taping  USD    6000   0  29
# 71    ACA-5036-A2-CC成品  ACM4-5036-A1-CC-S Taping  USD      25  10  29
# 86    ACA-5036-A2-CC成品  ACM4-5036-A1-CC-S Taping  USD    6000   0  29
# 137          ACA5036成品   ACD-3216-A1-CC-S Taping  USD       5   4  29
# 138          ACA5036成品   ACD-5036-A3-CC-S Taping  USD       5   4  29
# ...                ...                       ...  ...     ...  ..  ..
# 1521             GSM成品          WA-P-U6-02-003-A  USD   20000   0  29
# 1522             GSM成品      WAG-F-LTE10-00-052-I  USD  150000   0  29
# 1523             GSM成品      WAG-F-LTE10-00-053-I  USD  150000   0  29
# 1524             GSM成品       WAG-F-LAG0-00-042-I  USD  150000   0  29
# 1525         Chip Ant.          ACE-3505-P1-PF-S  USD    2100   0  29
#
#       本國幣別NTD                  客戶料號 客戶希交日 Term
# 13      25929  ACM4-5036-A1-CC-S Ta   NaT  EXW
# 71       7202     ACM4-5036-A1-CC-S   NaT  EXW
# 86      25929  ACM4-5036-A1-CC-S Ta   NaT  EXW
# 137       576  ACD-3216-A1-CC-S  Ta   NaT  EXW
# 138       576  ACD-5036-A3-CC-S  Ta   NaT  EXW
# ...       ...                   ...   ...  ...
# 1521    92192      WA-P-U6-02-003-A   NaT  EXW
# 1522   229039              RC100808   NaT  EXW
# 1523   177181              RC100807   NaT  EXW
# 1524   112359              RC100806   NaT  EXW
# 1525    21175      ACE-3505-P1-PF-S   NaT  EXW
#
# [1518 rows x 25 columns]

# %%
code = pd.read_excel(r"C:\Users\kaihsu\Desktop\BU_code.xlsx")

# %%
bu_code = dict(zip(code.Code, code.BG))
cus_code = dict(zip(code.Cus, code.Group))

# %%
def zhunan_component_processing(file_path, file_name, export_path):
    code = pd.read_excel("BU_code.xlsx")
    bu_code = dict(zip(code.Code, code.BG))
    cus_code = dict(zip(code.Cus, code.Group))
    df = pd.read_excel(file_path)
    #     df.keys()
    #     df = df['axmr4301']
    #     columns = df.iloc[0,:].tolist()
    #     df.columns = columns
    #     df = df.drop(0, axis=0) #去掉最上面沒有用的row
    df.columns = df.columns.str.strip()  # 去掉欄位名稱的空白

    df['開單日期'] = pd.to_datetime(df['開單日期'], yearfirst=True, unit='D')
    df['預交日期'] = pd.to_datetime(df['預交日期'], yearfirst=True, unit='D')
    df['客戶希交日'] = pd.to_datetime(df['客戶希交日'], yearfirst=True, errors='coerce', unit='D')
    df['交期變更'] = pd.to_datetime(df['交期變更'], yearfirst=True, errors='coerce', unit='D')
    keep_columns = ['狀態', '銷售單號', '月份', '開單日期', '預交日期', '交期變更', '客戶名稱', '負責業務', '交貨方式', '產品分類', '品名', '幣別', '數量', '單位',
                    '單價', '匯率', '本國幣別 NTD', '客戶料號', '客戶希交日', 'Term']
    df = df[keep_columns]  # 需要留下來的欄位建立新表格

    # columns_strip = ['狀態', '銷售單號', '客戶名稱', '負責業務', '交貨方式',
    #                  '產品分類', '品名', '幣別', '單位', '客戶料號',
    #                  'Term']
    # df_strip = df[columns_strip]
#     columns_keep = ['開單日期', '預交日期', '交期變更', '月份', '數量', '單價', '匯率', '本國幣別 NTD', '客戶希交日']
#     df_keep = df[columns_keep]
#     df_strip = df_strip.applymap(lambda x: x.strip())
#     df = pd.concat([df_strip, df_keep], axis=1)

    df_unit_change = df[df['單位'] == 'KPCS']
    df_keep_unit = df[~(df['單位'] == 'KPCS')]

    df_unit_change['數量'] = df_unit_change['數量'].map(lambda x: x * 1000)
    df_unit_change['單價'] = df_unit_change['單價'].map(lambda x: x / 1000)
    df_unit_change['單位'] = df_unit_change['單位'].str.replace('KPCS', 'PCS')

    df = pd.concat([df_unit_change, df_keep_unit], axis=0)

    append_dict = {0: 'Category', 1: 'BG', 2: 'Subcategory', 3: 'Group', 4: '預交年份', 5: '預交月份', }
    for k, v in append_dict.items():
        df.insert(k, v, value=None)

    df = df.drop('單位', axis=1)

    columns = ['Category', 'BG', 'Subcategory', 'Group', '狀態', '銷售單號', '月份', '開單日期', '預交日期', '預交年份', '預交月份', '交期變更',
           '客戶名稱', '負責業務', '交貨方式', '產品分類', '品名', '幣別', '數量', '單價', '集團匯率(NTD)', '金額*集團匯率(NTD)', '客戶料號', '客戶希交日', 'Term']
    result = df.reindex(columns=columns)
    result['Category'] = result['產品分類'].map(lambda x: x[0:4])
    result['BG'] = result['Category'].map(bu_code)
    result['Group'] = result['客戶名稱'].map(cus_code)
    result['負責業務'] = result['負責業務'].map(lambda x: '鄭里緗' if x == '沈思明' else x)
    result = result[result['負責業務'].isin(['鄭里緗', '許凱智', '墨漢雷迪'])]
    result['預交年份'] = result['預交日期'].dt.year
    result['預交月份'] = result['預交日期'].dt.month_name()
    result.columns = ['Category', 'BG', 'Subcategory', 'Group', '狀態', '銷售單號', '月份', '開單日期',
       '預交日期', '預交年份', '預交月份', '交期變更', '客戶名稱', '負責業務', '交貨方式', '產品分類', '品名',
       '幣別', '數量', '單價', '匯率', '本國幣別NTD', '客戶料號', '客戶希交日', 'Term']
    result['數量'] = result['數量'].astype(int)
    result['本國幣別NTD'] = result['本國幣別NTD'].astype(int)
    # print('請選擇輸出資料夾')
    # export_path = get_file_path()
    # export_file_name = 'C:\\Users\\kaihsu\\Desktop\\業績總表\\' + file_name # PC使用
    export_file_name = export_path + '/' + file_name  # Mac使用
    result.to_excel(export_file_name, index=False)

# %%
def antenna_processing(file_path, file_name, export_path):
    code = pd.read_excel("BU_code.xlsx")
    bu_code = dict(zip(code.Code, code.BG))
    cus_code = dict(zip(code.Cus, code.Group))
    df = pd.read_excel(file_path, header=1)
    #     df.keys()
    #     df = df['axmr4301']
    #     columns = df.iloc[0,:].tolist()
    #     df.columns = columns
    #     df = df.drop(0, axis=0) #去掉最上面沒有用的row
    df.columns = df.columns.str.strip()  # 去掉欄位名稱的空白
    # df = df.drop(df.columns[-3:], axis=1)

    # df['開單日期'] = pd.to_datetime(df['開單日期'], yearfirst=True, unit='D')
    # df['預交日期'] = pd.to_datetime(df['預交日期'], yearfirst=True, unit='D')
    # df['客戶希交日'] = pd.to_datetime(df['客戶希交日'], yearfirst=True, errors='coerce', unit='D')
    # df['交期變更'] = pd.to_datetime(df['交期變更'], yearfirst=True, errors='coerce', unit='D')
    keep_columns = ['狀態', '銷售單號', '月份', '開單日期', '預交日期', '交期變更', '客戶名稱', '負責業務', '交貨方式', '產品分類', '品名', '幣別', '數量', '單位',
                    '單價', '集團匯率(NTD)', '金額*集團匯率(NTD)', '客戶料號', '客戶希交日', 'Term']
    df = df[keep_columns]  # 需要留下來的欄位建立新表格

    # columns_strip = ['狀態', '銷售單號', '客戶名稱', '負責業務', '交貨方式',
    #                  '產品分類', '品名', '幣別', '單位', '客戶料號',
    #                  'Term']
    # df_strip = df[columns_strip]
    # columns_keep = ['開單日期', '預交日期', '交期變更', '月份', '數量', '單價', '匯率', '本國幣別 NTD', '客戶希交日']
    # df_keep = df[columns_keep]
    # df_strip = df_strip.applymap(lambda x: x.strip())
    # df_strip['負責業務'] = df_strip['負責業務'].apply(change_name)
    # df = pd.concat([df_strip, df_keep], axis=1)
    # df = df[(df['負責業務'].str.contains('許凱智|墨漢雷迪|楊婉芬|沈思明|周彥宏'))].reset_index()

    df_unit_change = df[df['單位'] == 'KPCS']
    df_keep_unit = df[~(df['單位'] == 'KPCS')]

    df_unit_change['數量'] = df_unit_change['數量'].map(lambda x: x * 1000)
    df_unit_change['單價'] = df_unit_change['單價'].map(lambda x: x / 1000)
    df_unit_change['單位'] = df_unit_change['單位'].str.replace('KPCS', 'PCS')

    df = pd.concat([df_unit_change, df_keep_unit], axis=0)

    append_dict = {0: 'Category', 1: 'BG', 2: 'Subcategory', 3: 'Group', 4: '預交年份', 5: '預交月份', }
    for k, v in append_dict.items():
        df.insert(k, v, value=None)

    df = df.drop('單位', axis=1)

    columns = ['Category', 'BG', 'Subcategory', 'Group', '狀態', '銷售單號', '月份', '開單日期', '預交日期', '預交年份', '預交月份', '交期變更',
               '客戶名稱', '負責業務', '交貨方式', '產品分類', '品名', '幣別', '數量', '單價', '集團匯率(NTD)', '金額*集團匯率(NTD)', '客戶料號', '客戶希交日',
               'Term']
    result = df.reindex(columns=columns)
    result['Category'] = result['產品分類'].map(lambda x: x[0:4])
    result['BG'] = result['Category'].map(bu_code)
    result['Group'] = result.apply(lambda x: cus_code[x['客戶名稱']] if x['客戶名稱'] in cus_code.keys() else x['客戶名稱'], axis=1)
    result['負責業務'] = result['負責業務'].map(lambda x: '許凱智' if x == '楊婉芬' or x == '周彥宏' else x)
    result = result[result['負責業務'].isin(['鄭里緗', '許凱智', '墨漢雷迪'])]
    result['預交年份'] = result['預交日期'].dt.year
    result['預交月份'] = result['預交日期'].dt.month_name()
    result.columns = ['Category', 'BG', 'Subcategory', 'Group', '狀態', '銷售單號', '月份', '開單日期',
                      '預交日期', '預交年份', '預交月份', '交期變更', '客戶名稱', '負責業務', '交貨方式', '產品分類', '品名',
                      '幣別', '數量', '單價', '匯率', '本國幣別NTD', '客戶料號', '客戶希交日', 'Term']
    result['數量'] = result['數量'].astype(int)
    result['本國幣別NTD'] = result['本國幣別NTD'].astype(int)
    # print('請選擇輸出資料夾')
    # export_path = get_file_path()
    # export_file_name = 'C:\\Users\\kaihsu\\Desktop\\業績總表\\' + file_name
    export_file_name = export_path + '/' + file_name  # Mac使用
    result.to_excel(export_file_name, index=False)

# %% [markdown]
# ## 一次處理所有檔案

# %%
'''一次整理所有的檔案'''

def preprocessing_data():
    print('Please select the files from the folder to extract!')
    file_paths = get_file_paths()
    y = display(file_paths)
    a, b, c = map(int, input('Please input numbers to decide the processing order and press "Enter": (Component, RF)\n Example: 3 2 1\n\n').split())
    preprocessing_order = [a, b, c]
    print('Please select the folder to export the files.')
    export_path = get_file_path()
    for file in preprocessing_order:
        if preprocessing_order.index(file) == 1 or preprocessing_order.index(file) == 2:
            file_path = y[file]
            file_name = y[file].split('/')[-1].split('.')[0] + '_revised.xlsx'
            zhunan_component_processing(file_path, file_name, export_path)
        else:
            file_path = y[file]
            file_name = y[file].split('/')[-1].split('.')[0] + '_revised.xlsx'
            antenna_processing(file_path, file_name, export_path)

# %%
file_paths = get_file_paths()
y = display(file_paths)
a, b, c = map(int, input('Please input numbers to decide the processing order and press "Enter": (Component, RF)\n Example: 3 2 1\n\n').split())
preprocessing_order = [a, b, c]
print('Please select the folder to export the files.')
export_path = get_file_path()
# Out:
# 1 RF
# 2 訂單出貨明細_axmr4301_1D5E00F5F903399240A7D99362DBDCE8
# 3 訂單出貨明細_axmr4301_2019
# Please input numbers to decide the processing order and press "Enter": (Component, RF)
#  Example: 3 2 1
#
# 2 3 1
# Please select the folder to export the files.

# %%
for file in preprocessing_order:
     if preprocessing_order.index(file) == 0 or preprocessing_order.index(file) == 1:
        file_path = y[file]
        file_name = y[file].split('/')[-1].split('.')[0] + '_revised.xlsx'
        zhunan_component_processing(file_path, file_name, export_path)
        print(file_path, file_name, export_path)
    else:
        file_path = y[file]
        file_name = y[file].split('/')[-1].split('.')[0] + '_revised.xlsx'
        antenna_processing(file_path, file_name, export_path)
        print(file_path, file_name, export_path)
# Out:
#   File "<tokenize>", line 7
#     else:
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
preprocessing_order.index(3)
# Out:
# 1

# %%
'''將所有檔案的資料合併為一個檔案'''
def merge_files():
    print('Please select the files for combination.')
    files = get_file_paths()
    n = 1
    combine_files = {}
    for f in files:
        file_name = 'df' + str(n)
        combine_files.setdefault(file_name, pd.read_excel(f))
        n += 1
    final = pd.concat(combine_files)
    print('Please select the folder to export')
    folder_name = get_file_path()
    final.to_excel(folder_name + '/匯總數據_final.xlsx', index=False)
    print('Export has been finished.')
