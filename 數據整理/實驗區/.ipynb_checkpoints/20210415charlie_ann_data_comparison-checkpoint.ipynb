# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
charlie = pd.read_excel(r"C:\Users\kaihsu\Desktop\業績總表\RF.xlsx", None)

# %%
charlie = charlie['RF']

# %%
ann = pd.read_excel(r"C:\Users\kaihsu\Desktop\ann_revised.xlsx", None)

# %%
ann = ann['工作表1']

# %%
ann.columns = ann.columns.str.strip()

# %%
ann.shape
# Out:
# (2597, 61)

# %%
charlie.shape
# Out:
# (1168, 68)

# %%
len(ann.columns)
# Out:
# 61

# %%
len(charlie.columns)
# Out:
# 68

# %%
ann.columns
# Out:
# Index(['營運中心', '狀態', '銷售單號', '項次', '月份', '開單日期', '預交日期', '交期變更', '客戶名稱',
#        '業務代號', '負責業務', '客戶單號', '客戶訂單項次', '組別', '銷售類', '交貨方式', '料號', '產品分類',
#        '品名', '單位', '幣別', '數量', '已出數量', '未出數', '單價', '金額', '匯率', '本國幣別', '客戶料號',
#        '其他分群一(接單業務)', '客戶編號', '訂單業務', '出通單號', '代理商編號', '發票號碼', 'INVOICE',
#        '客戶希交日', 'Term', '備註', 'C.C.', '客戶專案名稱', '原始希交日', 'HSF編號(報價單)',
#        'HSF編號(最新)', '產品類別', '出通單日', '出貨單號', '新單別', '車用', '用戶端車型', '天線擺放位置',
#        'Rebate', '集團匯率', '集團匯率*金額', '資料所有者', '資料修改者', '出貨日期', '送貨客戶編號',
#        '送貨客戶名稱', '產品分類1', '組別1'],
#       dtype='object')

# %%
charlie.columns
# Out:
# Index(['營運中心', '狀態', '銷售單號', '銷售項次', '銷售月份', '開單日期', '預交日期', '交期變更', '客戶名稱',
#        '業務代號', '負責業務', '客戶訂單', '客戶訂單項次', '業務部門', '銷售類', '交貨方式', '料號', '產品分類',
#        '品名', '銷售單位', '幣別', '數量', '已出數量', '未出數', '單價', '金額', '訂單匯率', '金額*訂單匯率',
#        '客戶料號', '其它分群一碼(接單業務)', '帳款客戶編號', '業務名稱', '出通單號', '代理商編號', '發票號碼',
#        'INVOICE號碼', '客戶希交日', 'TERM', '備註', 'C.C', '客戶專案名稱', '原始希交日',
#        'HSF編號(報價單)', 'HSF編號(最新)', '產品類別', '出通單日', '出貨單號', '舊系統單號', '車用',
#        '用戶端車型', '天線擺放位置', 'REBATE', '集團匯率', '集團匯率*金額', '資料所有者', '資料修改者',
#        '出貨日期', '送貨客戶編號', '送貨客戶名稱', '數量(舊系統)', '來源單據', 'BU', 'HUB領',
#        'INVOICE項次', '年', '月', '組別2', 'RF/元件'],
#       dtype='object')

# %%
ann.rename(columns={'項次': '銷售項次'}, inplace=True)

# %%
x = charlie.columns.to_list()
y = ann.columns.to_list()

for item in x:
    if item in y:
        pass
    else:
        x.remove(item)

# %%
test = charlie[x]

# %%
pd.merge(test, ann)
# Out:
#         營運中心    狀態              銷售單號  銷售項次       開單日期       預交日期       交期變更  \
# 0     HOLYTW  04未出  EHRAN-2010000001     1 2020-10-26 2021-04-15 2021-03-22
# 1     HOLYTW  01已出  EHRAN-2011000003     1 2020-11-19 2021-01-08 2020-12-31
# 2     HOLYTW  01已出  EHRAN-2011000003     6 2020-11-19 2021-01-08 2020-12-31
# 3     HOLYTW  01已出  EHRAN-2011000004     1 2020-11-10 2021-01-04        NaT
# 4     HOLYTW  01已出  EHRAN-2011000004     2 2020-11-10 2021-01-04        NaT
# ...      ...   ...               ...   ...        ...        ...        ...
# 1149  HOLYTW  12已出        YT220A0001    30 2020-10-19 2020-12-17 2020-12-11
# 1150  HOLYTW  12已出        YT220A0001    31 2020-10-19 2020-12-17 2020-12-11
# 1151  HOLYTW  12已出        YT220A0001    32 2020-10-19 2020-12-17 2020-12-11
# 1152  HOLYTW  12已出        YT220A0001    33 2020-10-19 2020-12-17 2020-12-11
# 1153  HOLYTW  12已出        YT220A0001    34 2020-10-19 2020-12-17 2020-12-11
#
#           客戶名稱   業務代號  負責業務  客戶訂單項次 銷售類      交貨方式            料號     產品分類  \
# 0         M.S.  A4685  墨漢雷迪     NaN  外銷  AIR-FWRD  H00000005208    GSM成品
# 1     Univa Te  A4685  墨漢雷迪     1.0  外銷       DHL  H00000005379    GSM成品
# 2     Univa Te  A4685  墨漢雷迪     NaN  外銷       DHL  H00000005485     內置成品
# 3         M.S.  A4685  墨漢雷迪     NaN  外銷       DHL  H00000005245  PATCH成品
# 4         M.S.  A4685  墨漢雷迪     NaN  外銷       DHL  H00000005239    GSM成品
# ...        ...    ...   ...     ...  ..       ...           ...      ...
# 1149  TELTONIK  A5048   許凱智    17.0  外銷       DHL  000821107046    DPA成品
# 1150  TELTONIK  A5048   許凱智    17.0  外銷       DHL  000821107046    DPA成品
# 1151  TELTONIK  A5048   許凱智    17.0  外銷       DHL  000821107046    DPA成品
# 1152  TELTONIK  A5048   許凱智    17.0  外銷       DHL  000821107046    DPA成品
# 1153  TELTONIK  A5048   許凱智    17.0  外銷       DHL  000821107046    DPA成品
#
#                                  品名   幣別      數量    已出數量  未出數    單價      金額  \
# 0                WA-P-LTE9-02-004-A  USD   100.0     0.0  100  1.00   100.0
# 1     WAG-P-LTE10-00-001 Test Board  USD     1.0     1.0    0  0.60     0.6
# 2      ACE-3505-P1-PF-S  Test Board  USD     5.0     5.0    0  0.64     3.2
# 3              PA1590MQ4G-118-2KP-A  USD   100.0   100.0    0  0.49    49.0
# 4               WA-F-LTE10-02-016-A  USD   100.0   100.0    0  0.22    22.0
# ...                             ...  ...     ...     ...  ...   ...     ...
# 1149           RFDPA171300SBAB823J4  USD  3500.0  3500.0    0  0.73  2555.0
# 1150           RFDPA171300SBAB823J4  USD  3500.0  3500.0    0  0.73  2555.0
# 1151           RFDPA171300SBAB823J4  USD  3500.0  3500.0    0  0.73  2555.0
# 1152           RFDPA171300SBAB823J4  USD  3500.0  3500.0    0  0.73  2555.0
# 1153           RFDPA171300SBAB823J4  USD  1000.0  1000.0    0  0.73   730.0
#
#         金額*訂單匯率                           客戶料號 帳款客戶編號                出通單號  \
# 0      2887.500             WA-P-LTE9-02-004-A  JZ009                 NaN
# 1        17.274  WAG-P-LTE10-00-001 Test Board  HX003  EHRIN-2101000040-1
# 2        92.128   ACE-3505-P1-PF-S  Test Board  HX003  EHRIN-2101000040-2
# 3      1413.160           PA1590MQ4G-118-2KP-A  JZ009  EHRIN-2101000037-1
# 4       634.480            WA-F-LTE10-02-016-A  JZ009  EHRIN-2101000037-2
# ...         ...                            ...    ...                 ...
# 1149  73967.250           RFDPA171300SBAB823J4  EZ061       YT320C0031-30
# 1150  73967.250           RFDPA171300SBAB823J4  EZ061       YT320C0032-31
# 1151  73967.250           RFDPA171300SBAB823J4  EZ061       YT320C0033-32
# 1152  73967.250           RFDPA171300SBAB823J4  EZ061       YT320C0034-33
# 1153  21133.500           RFDPA171300SBAB823J4  EZ061       YT320C0035-34
#
#       代理商編號 發票號碼      客戶希交日                              備註 客戶專案名稱      原始希交日  \
# 0       NaN  NaN 2021-04-15                             NaN    NaN 2021-04-15
# 1       NaN  NaN 2021-01-08                             NaN    NaN 2021-01-08
# 2       NaN  NaN 2021-01-08                             NaN    NaN 2021-01-08
# 3       NaN  NaN 2021-01-04                             NaN    NaN        NaT
# 4       NaN  NaN 2021-01-04                             NaN    NaN        NaT
# ...     ...  ...        ...                             ...    ...        ...
# 1149    NaN  NaN 2020-12-17  DHL Express ACC NO : 961797164    NaN 2020-12-17
# 1150    NaN  NaN 2020-12-17  DHL Express ACC NO : 961797164    NaN 2020-12-17
# 1151    NaN  NaN 2020-12-17  DHL Express ACC NO : 961797164    NaN 2020-12-17
# 1152    NaN  NaN 2020-12-17  DHL Express ACC NO : 961797164    NaN 2020-12-17
# 1153    NaN  NaN 2020-12-17  DHL Express ACC NO : 961797164    NaN 2020-12-17
#
#       HSF編號(報價單)       HSF編號(最新)        產品類別       出通單日                出貨單號  \
# 0            NaN  HSF-S201710012  AUTOMOTIVE        NaT                 NaN
# 1            NaN  HSF-S201905001  AUTOMOTIVE 2021-01-08  EHSGN-2101000038-1
# 2            NaN  HSF-S201905001  AUTOMOTIVE 2021-01-08  EHSGN-2101000038-2
# 3            NaN  HSF-S201710012  AUTOMOTIVE 2021-01-07  EHSGN-2101000025-1
# 4            NaN  HSF-S201710012  AUTOMOTIVE 2021-01-07  EHSGN-2101000025-2
# ...          ...             ...         ...        ...                 ...
# 1149         NaN  HSF-S202005002  AUTOMOTIVE 2020-12-17       Y2420C0027-30
# 1150         NaN  HSF-S202005002  AUTOMOTIVE 2020-12-17       Y2420C0028-31
# 1151         NaN  HSF-S202005002  AUTOMOTIVE 2020-12-17       Y2420C0029-32
# 1152         NaN  HSF-S202005002  AUTOMOTIVE 2020-12-17       Y2420C0030-33
# 1153         NaN  HSF-S202005002  AUTOMOTIVE 2020-12-17       Y2420C0031-34
#
#      車用  用戶端車型  天線擺放位置    集團匯率    集團匯率*金額 資料所有者 資料修改者       出貨日期 送貨客戶編號  \
# 0     N    NaN     NaN  28.535   2853.500   蔡鈺惠   系統管        NaT  JZ009
# 1     N    NaN     NaN  28.535     17.121   蔡鈺惠   系統管 2021-01-08  HX003
# 2     N    NaN     NaN  28.535     91.312   蔡鈺惠   系統管 2021-01-08  HX003
# 3     N    NaN     NaN  28.535   1398.215   蔡鈺惠   蔡鈺惠 2021-01-07  JZ009
# 4     N    NaN     NaN  28.535    627.770   蔡鈺惠   蔡鈺惠 2021-01-07  JZ009
# ...  ..    ...     ...     ...        ...   ...   ...        ...    ...
# 1149  N    NaN     NaN  28.535  72906.925   林康萍   林康萍 2020-12-15  EZ061
