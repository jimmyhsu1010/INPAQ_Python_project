# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import time

# %%
import concurrent.futures

# %%
# url = 'https://item.tuhu.cn/Products/TR-JJ-HT5/1.html'
headers = {'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 11_2_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.114 Safari/537.36', 
          'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9', 
          'accept-encoding': 'gzip, deflate, br', 'accept-language': 'zh-TW,zh;q=0.9,ru;q=0.8,en-US;q=0.7,en;q=0.6,ja;q=0.5', 
          'upgrade-insecure-requests': '1'}

# %%
def get_products():
    links = []
    for i in range(1, 268):
        url = 'https://item.tuhu.cn/Tires/' + str(i) + '/f0.html?ws=home&ln=paneltire&na=alltire'
        res = requests.get(url, headers=headers)
        soup = bs(res.content, 'html.parser')
        table = soup.find('table', class_='List')
        tds = table.find_all('td', class_='td1')
        for t in tds:
            link = t.find('a')['href']
            links.append(link)
        time.sleep(1)
    return links

# %%
links = get_products()

# %%
def parse(links):
    contents = []
    for link in links:
        res = requests.get(url=link, headers=headers)
        soup = bs(res.content, 'html.parser')
        properties = soup.find('div', class_='properties').find_all('li')
        keys = []
        values = []
        for p in properties:
            text = p.text.split('：')
            keys.append(text[0])
            values.append(text[1])
        data = dict(zip(keys, values))

        price_tag = soup.find('div', class_='price')
        price = price_tag.text.strip()
        data.setdefault('Price', price)
        contents.append(data)
    return contents

# %%
contents = parse(links)

# %%
contents

# %%
def parse_item(link):
    res = requests.get(url=link, headers=headers)
    soup = bs(res.content, 'html.parser')
    properties = soup.find('div', class_='properties').find_all('li')
    keys = []
    values = []
    for p in properties:
        text = p.text.split('：')
        keys.append(text[0])
        values.append(text[1])
    data = dict(zip(keys, values))

    price_tag = soup.find('div', class_='price')
    price = price_tag.text.strip()
    data.setdefault('Price', price)
    return data

# %%
with concurrent.futures.ThreadPoolExecutor(max_workers=20) as executor:
    results = list(executor.map(parse_item, links))

# %%
df = pd.DataFrame()
for result in results:
    df = df.append(result, ignore_index=True)
df
# Out:
#         Price 产品产地       产品规格              轮胎品牌    轮胎类别              轮胎花纹  \
# 0     ¥409.00   中国  225/65R17      固特异/Goodyear  商务型轿车胎             御乘SUV
# 1     ¥469.00  NaN  225/65R17        将军/General  城市SUV胎               HT5
# 2     ¥881.00  NaN  215/55R18  德国马牌/Continental  商务型轿车胎               MC5
# 3     ¥546.00  NaN  235/55R18         固铂/Cooper  运动型轿车胎  CS4 TOURING PLUS
# 4     ¥329.00  NaN  205/55R16        韩泰/Hankook  运动型轿车胎              H308
# ...       ...  ...        ...               ...     ...               ...
# 5324  ¥279.00  NaN  175/65R14        远致/HORIZON  运动型轿车胎       Silencer 01
# 5325  ¥509.00  NaN  225/50R17        远致/HORIZON  商务型轿车胎       Silencer 02
# 5326  ¥479.00  NaN  205/50R17        远致/HORIZON  商务型轿车胎       Silencer 02
# 5327  ¥289.00  NaN  185/65R14        远致/HORIZON  运动型轿车胎       Silencer 01
# 5328  ¥499.00  NaN  215/55R17        远致/HORIZON  商务型轿车胎       Silencer 02
#
#                 载重指数           速度级别 轮胎特点
# 0     102(最大载重850千克)  H(最高210公里/小时)  NaN
# 1     102(最大载重850千克)  H(最高210公里/小时)  NaN
# 2      95(最大载重690千克)  V(最高240公里/小时)  NaN
# 3     100(最大载重800千克)  V(最高240公里/小时)  NaN
# 4      91(最大载重615千克)  V(最高240公里/小时)  NaN
# ...              ...            ...  ...
# 5324   82(最大载重475千克)  H(最高210公里/小时)  NaN
# 5325   94(最大载重670千克)  V(最高240公里/小时)  NaN
# 5326   93(最大载重650千克)  W(最高270公里/小时)  NaN
# 5327   86(最大载重530千克)  H(最高210公里/小时)  NaN
# 5328   94(最大载重670千克)  V(最高240公里/小时)  NaN
#
# [5329 rows x 9 columns]

# %%
df.columns = df.columns.str.strip()

# %%
df['Price'] = df['Price'].str.replace('¥', '').str.replace('.00', '')

# %%
df['Price'] = df['Price'].str.replace(',', '')

# %%
df['Price'] = df['Price'].map(lambda x: 0 if x == '' else x)

# %%
df['Price'] = df['Price'].astype('int')

# %%
df
# Out:
#       Price 产品产地       产品规格              轮胎品牌    轮胎类别              轮胎花纹  \
# 0       409   中国  225/65R17      固特异/Goodyear  商务型轿车胎             御乘SUV
# 1       469  NaN  225/65R17        将军/General  城市SUV胎               HT5
# 2       881  NaN  215/55R18  德国马牌/Continental  商务型轿车胎               MC5
# 3       546  NaN  235/55R18         固铂/Cooper  运动型轿车胎  CS4 TOURING PLUS
# 4       329  NaN  205/55R16        韩泰/Hankook  运动型轿车胎              H308
# ...     ...  ...        ...               ...     ...               ...
# 5324    279  NaN  175/65R14        远致/HORIZON  运动型轿车胎       Silencer 01
# 5325    509  NaN  225/50R17        远致/HORIZON  商务型轿车胎       Silencer 02
# 5326    479  NaN  205/50R17        远致/HORIZON  商务型轿车胎       Silencer 02
# 5327    289  NaN  185/65R14        远致/HORIZON  运动型轿车胎       Silencer 01
# 5328    499  NaN  215/55R17        远致/HORIZON  商务型轿车胎       Silencer 02
#
#                 载重指数           速度级别 轮胎特点
# 0     102(最大载重850千克)  H(最高210公里/小时)  NaN
# 1     102(最大载重850千克)  H(最高210公里/小时)  NaN
# 2      95(最大载重690千克)  V(最高240公里/小时)  NaN
# 3     100(最大载重800千克)  V(最高240公里/小时)  NaN
# 4      91(最大载重615千克)  V(最高240公里/小时)  NaN
# ...              ...            ...  ...
# 5324   82(最大载重475千克)  H(最高210公里/小时)  NaN
# 5325   94(最大载重670千克)  V(最高240公里/小时)  NaN
# 5326   93(最大载重650千克)  W(最高270公里/小时)  NaN
# 5327   86(最大载重530千克)  H(最高210公里/小时)  NaN
# 5328   94(最大载重670千克)  V(最高240公里/小时)  NaN
#
# [5329 rows x 9 columns]

# %%
df.to_excel('tuhu_tires.xlsx', index=False)
