# %%
import requests
import json
from bs4 import BeautifulSoup as bs
from lxml import etree

# %% [markdown]
# ### 先把爬蟲前需要的資訊收集起來
# 1. 目標網址（這次的是AJAX網站，所以網址列的網址不是真正的目標，要開開發人員工具來檢視XHR
# 2. Payload訊息，需要點<font color=red>view source</font>來檢查原始的請求傳遞參數
# 3. Request headers需要設定<font color=red>user agent</font>和<font color=red>content type</font>
# 4. 注意請求方式，如果使用post，那就要用requests.post()
#
# ## <font color=red>注意</font>
# payload要用json格式帶入，方法有兩種：
# 1. import json，然後requests.post()裡面的`data=json.dumps(payload)`
# 2. requests.post()裡面使用`json=payload'

# %%
url = 'https://medium.com/_/graphql'
payload = {"operationName":"ExtendedFeedQuery","variables":{"items":[{"postId":"71ab2b25d663","topicId":""},{"postId":"e90431463924","topicId":""},{"postId":"3e07bdae552d","topicId":""},{"postId":"be0a205af03d","topicId":""},{"postId":"a993c9e3e02f","topicId":""},{"postId":"d9b536f91c2","topicId":""},{"postId":"a357562193a2","topicId":""},{"postId":"ab488fd553e2","topicId":""},{"postId":"5ad767af8564","topicId":""},{"postId":"ffd33fe37dec","topicId":""},{"postId":"6f746ea7d850","topicId":""},{"postId":"3cab1c76f1db","topicId":""},{"postId":"ac8e5bc9b455","topicId":""},{"postId":"2ac516e4d8ad","topicId":""},{"postId":"4848d8769eaa","topicId":""},{"postId":"8886a8b42715","topicId":""},{"postId":"2358f8451ef9","topicId":""},{"postId":"642172b959d2","topicId":""},{"postId":"98baed2b4b7a","topicId":""},{"postId":"8b592d50e530","topicId":""}]},"query":"query ExtendedFeedQuery($items: [ExtendedFeedItemOptions!]!) {\n  extendedFeedItems(items: $items) {\n    post {\n      ...PostListModulePostPreviewData\n      __typename\n    }\n    metadata {\n      topic {\n        id\n        name\n        __typename\n      }\n      __typename\n    }\n    __typename\n  }\n}\n\nfragment PostListModulePostPreviewData on Post {\n  id\n  firstPublishedAt\n  readingTime\n  createdAt\n  mediumUrl\n  previewImage {\n    id\n    __typename\n  }\n  title\n  collection {\n    id\n    domain\n    slug\n    name\n    navItems {\n      url\n      __typename\n    }\n    logo {\n      id\n      __typename\n    }\n    avatar {\n      id\n      __typename\n    }\n    __typename\n  }\n  creator {\n    id\n    name\n    username\n    imageId\n    mediumMemberAt\n    ...userUrl_user\n    __typename\n  }\n  visibility\n  isProxyPost\n  isLocked\n  ...HomeFeedItem_post\n  ...HomeReadingListItem_post\n  ...HomeTrendingModule_post\n  __typename\n}\n\nfragment HomeFeedItem_post on Post {\n  __typename\n  id\n  title\n  firstPublishedAt\n  mediumUrl\n  collection {\n    id\n    name\n    domain\n    logo {\n      id\n      __typename\n    }\n    __typename\n  }\n  creator {\n    id\n    name\n    username\n    imageId\n    mediumMemberAt\n    __typename\n  }\n  previewImage {\n    id\n    __typename\n  }\n  previewContent {\n    subtitle\n    __typename\n  }\n  readingTime\n  ...BookmarkButton_post\n  ...CreatorActionOverflowPopover_post\n  ...PostPresentationTracker_post\n  ...PostPreviewAvatar_post\n}\n\nfragment BookmarkButton_post on Post {\n  ...SusiClickable_post\n  ...WithSetReadingList_post\n  __typename\n  id\n}\n\nfragment SusiClickable_post on Post {\n  id\n  mediumUrl\n  ...SusiContainer_post\n  __typename\n}\n\nfragment SusiContainer_post on Post {\n  id\n  __typename\n}\n\nfragment WithSetReadingList_post on Post {\n  ...ReadingList_post\n  __typename\n  id\n}\n\nfragment ReadingList_post on Post {\n  __typename\n  id\n  readingList\n}\n\nfragment CreatorActionOverflowPopover_post on Post {\n  allowResponses\n  id\n  statusForCollection\n  isLocked\n  isPublished\n  clapCount\n  viewerClapCount\n  mediumUrl\n  pinnedAt\n  pinnedByCreatorAt\n  curationEligibleAt\n  mediumUrl\n  responseDistribution\n  shareKey\n  visibility\n  ...useIsPinnedInContext_post\n  pendingCollection {\n    id\n    name\n    viewerIsEditor\n    creator {\n      id\n      __typename\n    }\n    avatar {\n      id\n      __typename\n    }\n    domain\n    slug\n    __typename\n  }\n  creator {\n    id\n    isBlocking\n    ...MutePopoverOptions_creator\n    ...auroraHooks_publisher\n    __typename\n  }\n  collection {\n    id\n    viewerIsEditor\n    name\n    creator {\n      id\n      __typename\n    }\n    avatar {\n      id\n      __typename\n    }\n    domain\n    slug\n    ...MutePopoverOptions_collection\n    ...auroraHooks_publisher\n    __typename\n  }\n  ...ClapMutation_post\n  __typename\n}\n\nfragment MutePopoverOptions_creator on User {\n  id\n  isMuting\n  __typename\n}\n\nfragment MutePopoverOptions_collection on Collection {\n  id\n  viewerIsEditor\n  viewerIsMuting\n  __typename\n}\n\nfragment ClapMutation_post on Post {\n  __typename\n  id\n  clapCount\n  viewerClapCount\n  ...MultiVoteCount_post\n}\n\nfragment MultiVoteCount_post on Post {\n  id\n  ...PostVotersNetwork_post\n  __typename\n}\n\nfragment PostVotersNetwork_post on Post {\n  voterCount\n  viewerClapCount\n  recommenders {\n    name\n    __typename\n  }\n  __typename\n  id\n}\n\nfragment useIsPinnedInContext_post on Post {\n  id\n  collection {\n    id\n    __typename\n  }\n  pendingCollection {\n    id\n    __typename\n  }\n  pinnedAt\n  pinnedByCreatorAt\n  __typename\n}\n\nfragment auroraHooks_publisher on Publisher {\n  __typename\n  ... on Collection {\n    isAuroraEligible\n    isAuroraVisible\n    viewerIsEditor\n    __typename\n    id\n  }\n  ... on User {\n    isAuroraVisible\n    __typename\n    id\n  }\n}\n\nfragment PostPresentationTracker_post on Post {\n  id\n  visibility\n  previewContent {\n    isFullContent\n    __typename\n  }\n  collection {\n    id\n    slug\n    __typename\n  }\n  __typename\n}\n\nfragment PostPreviewAvatar_post on Post {\n  __typename\n  id\n  collection {\n    id\n    name\n    ...CollectionAvatar_collection\n    ...collectionUrl_collection\n    __typename\n  }\n  creator {\n    id\n    username\n    name\n    ...UserAvatar_user\n    ...userUrl_user\n    __typename\n  }\n}\n\nfragment CollectionAvatar_collection on Collection {\n  name\n  avatar {\n    id\n    __typename\n  }\n  ...collectionUrl_collection\n  __typename\n  id\n}\n\nfragment collectionUrl_collection on Collection {\n  id\n  domain\n  slug\n  __typename\n}\n\nfragment UserAvatar_user on User {\n  __typename\n  username\n  id\n  name\n  imageId\n  mediumMemberAt\n  ...userUrl_user\n}\n\nfragment userUrl_user on User {\n  __typename\n  id\n  customDomainState {\n    live {\n      domain\n      __typename\n    }\n    __typename\n  }\n  username\n  hasSubdomain\n}\n\nfragment HomeReadingListItem_post on Post {\n  id\n  title\n  creator {\n    id\n    name\n    username\n    ...UserAvatar_user\n    __typename\n  }\n  mediumUrl\n  createdAt\n  readingTime\n  collection {\n    id\n    name\n    navItems {\n      url\n      __typename\n    }\n    ...CollectionAvatar_collection\n    __typename\n  }\n  visibility\n  __typename\n}\n\nfragment HomeTrendingModule_post on Post {\n  id\n  ...HomeTrendingPostPreview_post\n  __typename\n}\n\nfragment HomeTrendingPostPreview_post on Post {\n  id\n  title\n  mediumUrl\n  readingTime\n  firstPublishedAt\n  ...PostPreviewAvatar_post\n  ...PostPresentationTracker_post\n  __typename\n}\n"}
headers = {"content-type": "application/json", "user-agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 11_2_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.90 Safari/537.36"}

# %%
response = requests.post(url, headers=headers, json=payload)

# %% [markdown]
# ### 返回的結果要用json來把他轉成python的字典

# %%
response = json.loads(response.content)

# %%
result = response["data"]["extendedFeedItems"]

# %%
response
# Out:
# {'data': {'extendedFeedItems': [{'post': {'id': '71ab2b25d663',
#      'firstPublishedAt': 1613716277356,
#      'readingTime': 3.4113207547169813,
#      'createdAt': 1613682729473,
#      'mediumUrl': 'https://forge.medium.com/a-mental-trick-to-make-any-task-less-intimidating-71ab2b25d663',
#      'previewImage': {'id': '1*Diwc1DIGQArX7GSHdVtlXA.jpeg',
#       '__typename': 'ImageMetadata'},
#      'title': 'A Mental Trick to Make Any Task Less Intimidating',
#      'collection': {'id': '3f6ecf56618',
#       'domain': 'forge.medium.com',
#       'slug': 'forge',
#       'name': 'Forge',
#       'navItems': [],
#       'logo': {'id': '1*1cWFkPZeJn7fQREuNyHHOw.png',
#        '__typename': 'ImageMetadata'},
#       'avatar': {'id': '1*uWbn_ZpGom5xlrE-bX-EuQ.jpeg',
#        '__typename': 'ImageMetadata'},
#       '__typename': 'Collection',
#       'viewerIsEditor': False,
#       'creator': {'id': 'c626e36ed20', '__typename': 'User'},
#       'viewerIsMuting': False,
#       'isAuroraEligible': True,
#       'isAuroraVisible': True},
#      'creator': {'id': '7ff56d802184',
#       'name': 'Laura Vanderkam',
#       'username': 'lauravanderkam',
#       'imageId': '0*F-96hvvSXAzZvkqn',
#       'mediumMemberAt': 0,
#       '__typename': 'User',
#       'customDomainState': None,
#       'hasSubdomain': False,
#       'isBlocking': None,
#       'isMuting': None,
#       'isAuroraVisible': True},
#      'visibility': 'LOCKED',
#      'isProxyPost': False,
#      'isLocked': True,
#      '__typename': 'Post',
#      'previewContent': {'subtitle': 'All you have to do is picture yourself on the other side',
#       '__typename': 'PreviewContent',
#       'isFullContent': False},
#      'readingList': 'READING_LIST_NONE',
#      'allowResponses': True,
#      'statusForCollection': 'APPROVED',
#      'isPublished': True,
#      'clapCount': 19785,
#      'viewerClapCount': 0,
#      'pinnedAt': 0,
#      'pinnedByCreatorAt': 0,
#      'curationEligibleAt': 1613688032763,
#      'responseDistribution': 'NOT_DISTRIBUTED',
#      'shareKey': None,
#      'pendingCollection': None,
#      'voterCount': 4283,
#      'recommenders': []},
#     'metadata': {'topic': None, '__typename': 'ExtendedFeedItemRankMetadata'},
#     '__typename': 'ExtendedFeedItem'},
#    {'post': {'id': 'e90431463924',
#      'firstPublishedAt': 1615315176976,
#      'readingTime': 7.837735849056604,
#      'createdAt': 1615312845060,
#      'mediumUrl': 'https://eand.co/how-britain-became-the-dumbest-society-in-the-world-e90431463924',
#      'previewImage': {'id': '1*c5mMVOqlNVU__isbUZdf1g.jpeg',
#       '__typename': 'ImageMetadata'},
#      'title': 'How Britain Became the Dumbest Society in the World',
#      'collection': {'id': '9b4cc1c6abbd',
#       'domain': 'eand.co',
#       'slug': 'eudaimonia-co',
#       'name': 'Eudaimonia and Co',
#       'navItems': [{'url': 'https://eand.co/the-story-eea04d97062b',
#         '__typename': 'NavItem'},
#        {'url': 'https://eand.co/eudaimonics-d55727be1233',
#         '__typename': 'NavItem'},
#        {'url': 'https://eand.co/the-fundamentals-370db41b2958',
#         '__typename': 'NavItem'},
#        {'url': 'https://eand.co/the-principles-ae48beb232f1',
#         '__typename': 'NavItem'},
#        {'url': 'https://eand.co/working-together-44e8d8010310',
#         '__typename': 'NavItem'}],
#       'logo': {'id': '1*f-DdsuscozAtG0quJB-dFw.png',
#        '__typename': 'ImageMetadata'},
#       'avatar': {'id': '1*-93e6dF2917cSfg3B3S4hg.png',
#        '__typename': 'ImageMetadata'},
#       '__typename': 'Collection',
#       'viewerIsEditor': False,
#       'creator': {'id': '41e01d325219', '__typename': 'User'},
#       'viewerIsMuting': False,
#       'isAuroraEligible': True,
#       'isAuroraVisible': False},
#      'creator': {'id': '41e01d325219',
#       'name': 'umair haque',
#       'username': 'umairh',
#       'imageId': '1*N3XzP2bucTYwTm8ZmUZkUA.jpeg',
#       'mediumMemberAt': 1602677875000,
#       '__typename': 'User',
#       'customDomainState': None,
#       'hasSubdomain': False,
#       'isBlocking': None,
#       'isMuting': None,
#       'isAuroraVisible': True},
#      'visibility': 'LOCKED',
#      'isProxyPost': False,
#      'isLocked': True,
#      '__typename': 'Post',
#      'previewContent': {'subtitle': 'Britain is Becoming the World’s Newest Failed State',
#       '__typename': 'PreviewContent',
#       'isFullContent': False},
#      'readingList': 'READING_LIST_NONE',
#      'allowResponses': True,
#      'statusForCollection': 'APPROVED',
#      'isPublished': True,
#      'clapCount': 20061,
#      'viewerClapCount': 0,
#      'pinnedAt': 0,
#      'pinnedByCreatorAt': 0,
#      'curationEligibleAt': 1615315175781,
#      'responseDistribution': 'NOT_DISTRIBUTED',
#      'shareKey': None,
#      'pendingCollection': None,
#      'voterCount': 3134,
#      'recommenders': []},
#     'metadata': {'topic': None, '__typename': 'ExtendedFeedItemRankMetadata'},
#     '__typename': 'ExtendedFeedItem'},
#    {'post': {'id': '3e07bdae552d',
#      'firstPublishedAt': 1615551367315,
#      'readingTime': 3.316981132075472,
#      'createdAt': 1614942778669,
#      'mediumUrl': 'https://forge.medium.com/please-be-cool-with-these-uncool-things-post-pandemic-3e07bdae552d',
#      'previewImage': {'id': '1*0QNTr31nePIdw6x0y2-61A.jpeg',
#       '__typename': 'ImageMetadata'},
#      'title': 'Please Be Cool With These Uncool Things Post-Pandemic',
#      'collection': {'id': '3f6ecf56618',
#       'domain': 'forge.medium.com',
#       'slug': 'forge',
#       'name': 'Forge',
#       'navItems': [],
#       'logo': {'id': '1*1cWFkPZeJn7fQREuNyHHOw.png',
#        '__typename': 'ImageMetadata'},
#       'avatar': {'id': '1*uWbn_ZpGom5xlrE-bX-EuQ.jpeg',
#        '__typename': 'ImageMetadata'},
#       '__typename': 'Collection',
#       'viewerIsEditor': False,
#       'creator': {'id': 'c626e36ed20', '__typename': 'User'},
#       'viewerIsMuting': False,
#       'isAuroraEligible': True,
#       'isAuroraVisible': True},
#      'creator': {'id': 'fe8d49f07105',
#       'name': 'Shani Silver',
#       'username': 'shanisilver',
#       'imageId': '1*Ghoj38ptvEmZFIvjVJwo9Q.jpeg',
#       'mediumMemberAt': 1490361758000,
#       '__typename': 'User',
#       'customDomainState': {'live': {'domain': 'shanisilver.medium.com',
#         '__typename': 'CustomDomain'},
#        '__typename': 'CustomDomainState'},
#       'hasSubdomain': True,
#       'isBlocking': None,
#       'isMuting': None,
#       'isAuroraVisible': True},
#      'visibility': 'LOCKED',
#      'isProxyPost': False,
#      'isLocked': True,
#      '__typename': 'Post',
#      'previewContent': {'subtitle': 'If you think you’re getting me back in zippy pants, you have another thing coming, good sir',
#       '__typename': 'PreviewContent',
#       'isFullContent': False},
#      'readingList': 'READING_LIST_NONE',
#      'allowResponses': True,
#      'statusForCollection': 'APPROVED',
#      'isPublished': True,
#      'clapCount': 13869,
#      'viewerClapCount': 0,
#      'pinnedAt': 1616515899334,
#      'pinnedByCreatorAt': 0,
#      'curationEligibleAt': 1615551366420,
#      'responseDistribution': 'NOT_DISTRIBUTED',
#      'shareKey': None,
#      'pendingCollection': None,
#      'voterCount': 2044,
#      'recommenders': []},
#     'metadata': {'topic': None, '__typename': 'ExtendedFeedItemRankMetadata'},
#     '__typename': 'ExtendedFeedItem'},
#    {'post': {'id': 'be0a205af03d',
#      'firstPublishedAt': 1613088076938,
#      'readingTime': 11.254716981132075,
#      'createdAt': 1600745254552,
#      'mediumUrl': 'https://betterprogramming.pub/flutter-is-about-to-win-over-the-web-be0a205af03d',
#      'previewImage': {'id': '1*jgFIhR2M19NPVsSVXOGe-w.png',
#       '__typename': 'ImageMetadata'},
#      'title': 'Flutter Is About To Win Over the Web',
#      'collection': {'id': 'd0b105d10f0a',
#       'domain': 'betterprogramming.pub',
#       'slug': 'better-programming',
#       'name': 'Better Programming',
#       'navItems': [{'url': 'https://betterprogramming.pub/archive',
#         '__typename': 'NavItem'},
#        {'url': 'https://betterprogramming.pub/write-for-us-5c4bcba59397',
#         '__typename': 'NavItem'},
#        {'url': 'https://betterprogramming.pub/better-programming-styleguide-suggestions-eada98e35150',
#         '__typename': 'NavItem'},
#        {'url': 'https://betterprogramming.pub/about', '__typename': 'NavItem'},
#        {'url': 'https://betterprogrammingjobs.com', '__typename': 'NavItem'}],
#       'logo': {'id': '1*S6X0W_XVeBUPe2Mz0hrufA.png',
#        '__typename': 'ImageMetadata'},
#       'avatar': {'id': '1*TyRLQdZO7NdPATwSeut8gg.png',
#        '__typename': 'ImageMetadata'},
#       '__typename': 'Collection',
#       'viewerIsEditor': False,
#       'creator': {'id': 'adeddd83f452', '__typename': 'User'},
#       'viewerIsMuting': False,
#       'isAuroraEligible': True,
#       'isAuroraVisible': False},
#      'creator': {'id': '3b186edf3d0',
#       'name': 'Lew C',
#       'username': 'lewwybogus',
#       'imageId': '0*zJO0p4vxCqIXuCIi.jpg',
#       'mediumMemberAt': 0,
#       '__typename': 'User',
#       'customDomainState': None,
#       'hasSubdomain': False,
#       'isBlocking': None,
#       'isMuting': None,
#       'isAuroraVisible': True},
#      'visibility': 'LOCKED',
#      'isProxyPost': False,
#      'isLocked': True,
#      '__typename': 'Post',
#      'previewContent': {'subtitle': 'The cross-platform framework offers the most compelling web development experience',
#       '__typename': 'PreviewContent',
#       'isFullContent': False},
#      'readingList': 'READING_LIST_NONE',
#      'allowResponses': True,
#      'statusForCollection': 'APPROVED',
#      'isPublished': True,
#      'clapCount': 5246,
#      'viewerClapCount': 0,
#      'pinnedAt': 0,
#      'pinnedByCreatorAt': 0,
#      'curationEligibleAt': 1612932750919,
#      'responseDistribution': 'NOT_DISTRIBUTED',
#      'shareKey': None,
#      'pendingCollection': None,
#      'voterCount': 1291,
#      'recommenders': []},
#     'metadata': {'topic': None, '__typename': 'ExtendedFeedItemRankMetadata'},
#     '__typename': 'ExtendedFeedItem'},
#    {'post': {'id': 'a993c9e3e02f',
#      'firstPublishedAt': 1612827421871,
#      'readingTime': 3.841509433962264,
#      'createdAt': 1612445230119,
#      'mediumUrl': 'https://medium.com/personal-growth/the-rule-of-70-20-10-a993c9e3e02f',
#      'previewImage': {'id': '0*R9RIwXfr2mgct33k',
#       '__typename': 'ImageMetadata'},
#      'title': 'The Rule of 70/20/10',
#      'collection': {'id': '120fbcaac315',
#       'domain': None,
#       'slug': 'personal-growth',
#       'name': 'Personal Growth',
#       'navItems': [{'url': 'https://medium.com/personal-growth/top-rated-personal-development-courses-87c9edb60afd',
#         '__typename': 'NavItem'},
#        {'url': 'https://medium.com/personal-growth/how-my-writing-paid-my-debt-and-for-my-first-house-76fac1eda64',
#         '__typename': 'NavItem'},
#        {'url': 'https://medium.com/personal-growth/investing-principles-that-have-returned-more-than-20-per-year-135def411b32',
#         '__typename': 'NavItem'},
#        {'url': 'https://medium.com/personal-growth/10-ways-to-make-your-day-more-meaningful-5e840e6a60b9',
#         '__typename': 'NavItem'},
#        {'url': 'https://medium.com/personal-growth/13-sensible-daily-habits-2ebaca1c9bcf',
#         '__typename': 'NavItem'},
#        {'url': 'https://medium.com/personal-growth/know-your-self-1e0b6ccd7361',
#         '__typename': 'NavItem'},
#        {'url': 'https://medium.com/personal-growth/support-for-personal-growth-publication-b0abd33f75b3',
#         '__typename': 'NavItem'},
#        {'url': 'https://postanly.substack.com', '__typename': 'NavItem'}],
#       'logo': {'id': '', '__typename': 'ImageMetadata'},
#       'avatar': {'id': '1*M1G7XIOUgEfa2SPuOyLYIg.jpeg',
#        '__typename': 'ImageMetadata'},
#       '__typename': 'Collection',
#       'viewerIsEditor': False,
#       'creator': {'id': '6f9214a674fa', '__typename': 'User'},
#       'viewerIsMuting': False,
#       'isAuroraEligible': False,
#       'isAuroraVisible': False},
#      'creator': {'id': 'e4d971c7eba7',
#       'name': 'Niklas Göke',
#       'username': 'ngoeke',
#       'imageId': '2*79It_OTPLUdtxMRUb4lu6Q.jpeg',
#       'mediumMemberAt': 1490903827000,
#       '__typename': 'User',
#       'customDomainState': {'live': {'domain': 'ngoeke.medium.com',
#         '__typename': 'CustomDomain'},
#        '__typename': 'CustomDomainState'},
#       'hasSubdomain': True,
#       'isBlocking': None,
#       'isMuting': None,
#       'isAuroraVisible': True},
#      'visibility': 'LOCKED',
#      'isProxyPost': False,
#      'isLocked': True,
#      '__typename': 'Post',
#      'previewContent': {'subtitle': 'Do important work or none at all',
#       '__typename': 'PreviewContent',
#       'isFullContent': False},
#      'readingList': 'READING_LIST_NONE',
#      'allowResponses': True,
#      'statusForCollection': 'APPROVED',
#      'isPublished': True,
#      'clapCount': 9722,
#      'viewerClapCount': 0,
#      'pinnedAt': 0,
#      'pinnedByCreatorAt': 0,
#      'curationEligibleAt': 1612797003111,
#      'responseDistribution': 'NOT_DISTRIBUTED',
#      'shareKey': None,
#      'pendingCollection': None,
#      'voterCount': 1754,
#      'recommenders': []},
#     'metadata': {'topic': None, '__typename': 'ExtendedFeedItemRankMetadata'},
#     '__typename': 'ExtendedFeedItem'},
#    {'post': {'id': 'd9b536f91c2',
#      'firstPublishedAt': 1613329680313,
#      'readingTime': 4.279245283018868,
#      'createdAt': 1613273002518,
#      'mediumUrl': 'https://medium.com/mind-cafe/three-things-in-life-that-arent-worth-the-effort-d9b536f91c2',
#      'previewImage': {'id': '1*Dv-iNtRbfeiko3E6uLdcXg.jpeg',
#       '__typename': 'ImageMetadata'},
#      'title': 'Three Things in Life That Aren’t Worth The Effort',
#      'collection': {'id': 'b5717b16a765',
#       'domain': None,
#       'slug': 'mind-cafe',
#       'name': 'Mind Cafe',
#       'navItems': [{'url': 'https://medium.com/mind-cafe/writing-for-mind-cafe-a5320ac4fa57',
#         '__typename': 'NavItem'},
#        {'url': 'https://medium.com/mind-cafe/our-purpose-at-mind-cafe-3ac38214e047',
#         '__typename': 'NavItem'},
#        {'url': 'https://medium.com/mind-cafe/1-to-1-writing-coaching-with-our-founder-adrian-drew-2150b1e3f3e2',
#         '__typename': 'NavItem'},
#        {'url': 'https://mindcafe.co/magazine', '__typename': 'NavItem'}],
#       'logo': {'id': '1*QI6Ea1mYV7zWQ96vNBcDoQ.png',
#        '__typename': 'ImageMetadata'},
#       'avatar': {'id': '1*8ndrLe4Ldljn8ba1A-FbFA.png',
#        '__typename': 'ImageMetadata'},
#       '__typename': 'Collection',
#       'viewerIsEditor': False,
#       'creator': {'id': 'd742ec3b7e2d', '__typename': 'User'},
#       'viewerIsMuting': False,
#       'isAuroraEligible': True,
#       'isAuroraVisible': False},
#      'creator': {'id': '51e7eb466f57',
#       'name': 'Sean Kernan',
#       'username': 'seanjkernan',
#       'imageId': '1*guKWDyFxW4c3NBQrrHt2PA.jpeg',
#       'mediumMemberAt': 1570133380000,
#       '__typename': 'User',
#       'customDomainState': {'live': {'domain': 'seanjkernan.medium.com',
#         '__typename': 'CustomDomain'},
#        '__typename': 'CustomDomainState'},
#       'hasSubdomain': True,
#       'isBlocking': None,
#       'isMuting': None,
#       'isAuroraVisible': True},
#      'visibility': 'LOCKED',
#      'isProxyPost': False,
#      'isLocked': True,
#      '__typename': 'Post',
#      'previewContent': {'subtitle': 'To be more efficient and happy, cut the waste and damaging activities from your life.',
#       '__typename': 'PreviewContent',
#       'isFullContent': False},
#      'readingList': 'READING_LIST_NONE',
#      'allowResponses': True,
#      'statusForCollection': 'APPROVED',
#      'isPublished': True,
#      'clapCount': 16728,
#      'viewerClapCount': 0,
#      'pinnedAt': 0,
#      'pinnedByCreatorAt': 0,
#      'curationEligibleAt': 1613329338841,
#      'responseDistribution': 'NOT_DISTRIBUTED',
#      'shareKey': None,
#      'pendingCollection': None,
#      'voterCount': 3360,
#      'recommenders': []},
#     'metadata': {'topic': None, '__typename': 'ExtendedFeedItemRankMetadata'},
#     '__typename': 'ExtendedFeedItem'},
#    {'post': {'id': 'a357562193a2',
#      'firstPublishedAt': 1615530748305,
#      'readingTime': 3.120754716981132,
#      'createdAt': 1615494054980,
#      'mediumUrl': 'https://forge.medium.com/the-weekend-experiment-that-will-change-your-life-a357562193a2',
#      'previewImage': {'id': '1*EyI0IeTCMNQe4wnIE0Wh4Q.jpeg',
#       '__typename': 'ImageMetadata'},
#      'title': 'The Weekend Experiment That Will Change Your Life',
#      'collection': {'id': '3f6ecf56618',
#       'domain': 'forge.medium.com',
#       'slug': 'forge',
#       'name': 'Forge',
#       'navItems': [],
#       'logo': {'id': '1*1cWFkPZeJn7fQREuNyHHOw.png',
#        '__typename': 'ImageMetadata'},
#       'avatar': {'id': '1*uWbn_ZpGom5xlrE-bX-EuQ.jpeg',
#        '__typename': 'ImageMetadata'},
#       '__typename': 'Collection',
#       'viewerIsEditor': False,
#       'creator': {'id': 'c626e36ed20', '__typename': 'User'},
#       'viewerIsMuting': False,
#       'isAuroraEligible': True,
#       'isAuroraVisible': True},
#      'creator': {'id': '7ff56d802184',
#       'name': 'Laura Vanderkam',
#       'username': 'lauravanderkam',
#       'imageId': '0*F-96hvvSXAzZvkqn',
#       'mediumMemberAt': 0,
#       '__typename': 'User',
#       'customDomainState': None,
#       'hasSubdomain': False,
#       'isBlocking': None,
#       'isMuting': None,
#       'isAuroraVisible': True},
#      'visibility': 'LOCKED',
#      'isProxyPost': False,
#      'isLocked': True,
#      '__typename': 'Post',
#      'previewContent': {'subtitle': 'You probably have more leisure time than you think. Here’s how to maximize it.',
#       '__typename': 'PreviewContent',
#       'isFullContent': False},
#      'readingList': 'READING_LIST_NONE',
#      'allowResponses': True,
#      'statusForCollection': 'APPROVED',
#      'isPublished': True,
#      'clapCount': 5479,
#      'viewerClapCount': 0,
#      'pinnedAt': 0,
#      'pinnedByCreatorAt': 0,
#      'curationEligibleAt': 1615495322523,
#      'responseDistribution': 'NOT_DISTRIBUTED',
#      'shareKey': None,
#      'pendingCollection': None,
#      'voterCount': 1188,
#      'recommenders': []},
#     'metadata': {'topic': None, '__typename': 'ExtendedFeedItemRankMetadata'},
#     '__typename': 'ExtendedFeedItem'},
#    {'post': {'id': 'ab488fd553e2',
#      'firstPublishedAt': 1612803543718,
#      'readingTime': 4.731132075471698,
#      'createdAt': 1612597598793,
#      'mediumUrl': 'https://medium.com/illumination-curated/north-korean-105-floor-hotel-of-doom-deserted-for-30-years-ab488fd553e2',
#      'previewImage': {'id': '1*bbGsIUnIQRA0RyrLToFcKA.png',
#       '__typename': 'ImageMetadata'},
#      'title': 'North Korean 105-floor ‘Hotel of Doom’ Deserted for 30 Years',
#      'collection': {'id': '9c1a7e787501',
#       'domain': None,
#       'slug': 'illumination-curated',
#       'name': 'ILLUMINATION-Curated',
#       'navItems': [{'url': 'https://medium.com/illumination-curated/tagged/self-improvement',
#         '__typename': 'NavItem'},
#        {'url': 'https://medium.com/illumination-curated/tagged/science',
#         '__typename': 'NavItem'},
#        {'url': 'https://medium.com/illumination-curated/tagged/philosophy',
#         '__typename': 'NavItem'},
#        {'url': 'https://medium.com/illumination-curated/tagged/technology',
#         '__typename': 'NavItem'},
#        {'url': 'https://medium.com/illumination-curated/tagged/poetry',
#         '__typename': 'NavItem'},
#        {'url': 'https://medium.com/illumination-curated/tagged/fiction',
#         '__typename': 'NavItem'},
#        {'url': 'https://medium.com/illumination-curated/tagged/business',
#         '__typename': 'NavItem'},
#        {'url': 'https://medium.com/illumination', '__typename': 'NavItem'}],
#       'logo': {'id': '1*TCHl-Kf5aBzymh3RCM5EYA.png',
#        '__typename': 'ImageMetadata'},
#       'avatar': {'id': '1*0g5Y17BfFM1LzNufQ0MP-Q.png',
#        '__typename': 'ImageMetadata'},
#       '__typename': 'Collection',
#       'viewerIsEditor': False,
#       'creator': {'id': 'dd3942a5498a', '__typename': 'User'},
#       'viewerIsMuting': False,
#       'isAuroraEligible': True,
#       'isAuroraVisible': False},
#      'creator': {'id': 'a7fbdcc560c1',
#       'name': 'Jason Ward',
#       'username': 'jrward42',
#       'imageId': '2*pX1nQxWQHfx3TqrLjq6Llw.jpeg',
#       'mediumMemberAt': 1573825289946,
#       '__typename': 'User',
#       'customDomainState': {'live': {'domain': 'jrward42.medium.com',
#         '__typename': 'CustomDomain'},
#        '__typename': 'CustomDomainState'},
#       'hasSubdomain': True,
#       'isBlocking': None,
#       'isMuting': None,
#       'isAuroraVisible': True},
#      'visibility': 'LOCKED',
#      'isProxyPost': False,
#      'isLocked': True,
#      '__typename': 'Post',
#      'previewContent': {'subtitle': 'It’s a Guinness record holder for world’s tallest unoccupied building',
#       '__typename': 'PreviewContent',
#       'isFullContent': False},
#      'readingList': 'READING_LIST_NONE',
#      'allowResponses': True,
#      'statusForCollection': 'APPROVED',
#      'isPublished': True,
#      'clapCount': 3286,
#      'viewerClapCount': 0,
#      'pinnedAt': 0,
#      'pinnedByCreatorAt': 0,
#      'curationEligibleAt': 1612768864062,
#      'responseDistribution': 'NOT_DISTRIBUTED',
#      'shareKey': None,
#      'pendingCollection': None,
#      'voterCount': 680,
#      'recommenders': []},
#     'metadata': {'topic': None, '__typename': 'ExtendedFeedItemRankMetadata'},
#     '__typename': 'ExtendedFeedItem'},
#    {'post': {'id': '5ad767af8564',
#      'firstPublishedAt': 1612669296592,
#      'readingTime': 4.973584905660378,
#      'createdAt': 1612668432433,
#      'mediumUrl': 'https://berniebleske.medium.com/we-now-have-a-4th-stage-of-existence-and-it-may-be-the-end-of-us-all-5ad767af8564',
#      'previewImage': {'id': '0*4FFTP-A5lCx9ip_F',
#       '__typename': 'ImageMetadata'},
#      'title': 'We Now Have a 4th Stage of Existence, and it may be the end of us all.',
#      'collection': None,
#      'creator': {'id': '4535659d24ba',
#       'name': 'Bernie Bleske',
#       'username': 'berniebleske',
#       'imageId': '1*qm9WO2oTtlGXcs3OqgNTMw.jpeg',
#       'mediumMemberAt': 1517065717000,
#       '__typename': 'User',
#       'customDomainState': {'live': {'domain': 'berniebleske.medium.com',
#         '__typename': 'CustomDomain'},
#        '__typename': 'CustomDomainState'},
#       'hasSubdomain': True,
#       'isBlocking': None,
#       'isMuting': None,
#       'isAuroraVisible': True},
#      'visibility': 'LOCKED',
#      'isProxyPost': False,
#      'isLocked': True,
#      '__typename': 'Post',
#      'previewContent': {'subtitle': 'We need a new plan for the last 30 years of life.',
#       '__typename': 'PreviewContent',
#       'isFullContent': False},
#      'readingList': 'READING_LIST_NONE',
#      'allowResponses': True,
#      'statusForCollection': 'PENDING',
#      'isPublished': True,
#      'clapCount': 3590,
#      'viewerClapCount': 0,
#      'pinnedAt': 0,
#      'pinnedByCreatorAt': 0,
#      'curationEligibleAt': 1612669295314,
#      'responseDistribution': 'NOT_DISTRIBUTED',
#      'shareKey': None,
#      'pendingCollection': {'id': '7b837cf1fd73',
#       '__typename': 'Collection',
#       'name': 'Noteworthy - The Journal Blog',
#       'viewerIsEditor': False,
#       'creator': {'id': 'f3a886c9aaff', '__typename': 'User'},
#       'avatar': {'id': '1*GZiYunj6bsak8RGuLyutkQ.png',
#        '__typename': 'ImageMetadata'},
#       'domain': 'blog.usejournal.com',
#       'slug': 'did-you-know-the-journal-blog'},
#      'voterCount': 601,
#      'recommenders': []},
#     'metadata': {'topic': None, '__typename': 'ExtendedFeedItemRankMetadata'},
#     '__typename': 'ExtendedFeedItem'},
#    {'post': {'id': 'ffd33fe37dec',
#      'firstPublishedAt': 1613830508618,
#      'readingTime': 4.207547169811321,
#      'createdAt': 1613813471139,
#      'mediumUrl': 'https://medium.com/illumination-curated/how-does-a-black-person-know-if-a-white-person-is-racist-ffd33fe37dec',
#      'previewImage': {'id': '0*yNQ3UdtoAXyB8Whx',
#       '__typename': 'ImageMetadata'},
#      'title': 'How Does A Black Person Know If A White Person Is Racist?',
#      'collection': {'id': '9c1a7e787501',
#       'domain': None,
#       'slug': 'illumination-curated',
#       'name': 'ILLUMINATION-Curated',
#       'navItems': [{'url': 'https://medium.com/illumination-curated/tagged/self-improvement',
#         '__typename': 'NavItem'},
#        {'url': 'https://medium.com/illumination-curated/tagged/science',
#         '__typename': 'NavItem'},
#        {'url': 'https://medium.com/illumination-curated/tagged/philosophy',
#         '__typename': 'NavItem'},
#        {'url': 'https://medium.com/illumination-curated/tagged/technology',
#         '__typename': 'NavItem'},
#        {'url': 'https://medium.com/illumination-curated/tagged/poetry',
#         '__typename': 'NavItem'},
#        {'url': 'https://medium.com/illumination-curated/tagged/fiction',
#         '__typename': 'NavItem'},
#        {'url': 'https://medium.com/illumination-curated/tagged/business',
#         '__typename': 'NavItem'},
#        {'url': 'https://medium.com/illumination', '__typename': 'NavItem'}],
#       'logo': {'id': '1*TCHl-Kf5aBzymh3RCM5EYA.png',
#        '__typename': 'ImageMetadata'},
#       'avatar': {'id': '1*0g5Y17BfFM1LzNufQ0MP-Q.png',
#        '__typename': 'ImageMetadata'},
#       '__typename': 'Collection',
#       'viewerIsEditor': False,
#       'creator': {'id': 'dd3942a5498a', '__typename': 'User'},
#       'viewerIsMuting': False,
#       'isAuroraEligible': True,
#       'isAuroraVisible': False},
#      'creator': {'id': 'cc05eae66368',
#       'name': 'Rebecca Stevens A.',
#       'username': 'rstevensalder',
#       'imageId': '1*vl0pj8YWTLq4k0XEkoGTtA@2x.jpeg',
#       'mediumMemberAt': 1573526036000,
#       '__typename': 'User',
#       'customDomainState': {'live': {'domain': 'rstevensalder.medium.com',
#         '__typename': 'CustomDomain'},
#        '__typename': 'CustomDomainState'},
#       'hasSubdomain': True,
#       'isBlocking': None,
#       'isMuting': None,
#       'isAuroraVisible': True},
#      'visibility': 'LOCKED',
#      'isProxyPost': False,
#      'isLocked': True,
#      '__typename': 'Post',
#      'previewContent': {'subtitle': 'We can tell within the first minute of meeting you',
#       '__typename': 'PreviewContent',
#       'isFullContent': False},
#      'readingList': 'READING_LIST_NONE',
#      'allowResponses': True,
#      'statusForCollection': 'APPROVED',
#      'isPublished': True,
#      'clapCount': 15704,
#      'viewerClapCount': 0,
#      'pinnedAt': 0,
#      'pinnedByCreatorAt': 0,
#      'curationEligibleAt': 1613819320912,
#      'responseDistribution': 'NOT_DISTRIBUTED',
#      'shareKey': None,
#      'pendingCollection': None,
#      'voterCount': 2212,
#      'recommenders': []},
#     'metadata': {'topic': None, '__typename': 'ExtendedFeedItemRankMetadata'},
#     '__typename': 'ExtendedFeedItem'},
#    {'post': {'id': '6f746ea7d850',
#      'firstPublishedAt': 1613719873205,
#      'readingTime': 5.032075471698113,
#      'createdAt': 1613700215956,
#      'mediumUrl': 'https://scribblr42.medium.com/the-future-of-dashboards-is-dashboardless-6f746ea7d850',
#      'previewImage': {'id': '1*2XRCZN7iMpEhHk7_xyII4w.png',
#       '__typename': 'ImageMetadata'},
#      'title': 'The Future of Dashboards is Dashboardless',
#      'collection': None,
#      'creator': {'id': '96ade76d46e1',
#       'name': 'Ravi Mistry',
#       'username': 'scribblr42',
#       'imageId': '1*7Bkqxb6Ss-15FSSmu-fW5A.jpeg',
#       'mediumMemberAt': 0,
#       '__typename': 'User',
#       'customDomainState': {'live': {'domain': 'scribblr42.medium.com',
#         '__typename': 'CustomDomain'},
#        '__typename': 'CustomDomainState'},
#       'hasSubdomain': True,
#       'isBlocking': None,
#       'isMuting': None,
#       'isAuroraVisible': True},
#      'visibility': 'PUBLIC',
#      'isProxyPost': False,
#      'isLocked': False,
#      '__typename': 'Post',
#      'previewContent': {'subtitle': 'Earlier this year I wrote a long read about where I feel data visualisation is in 2021. In this post, I mention two things that I want to…',
#       '__typename': 'PreviewContent',
#       'isFullContent': False},
#      'readingList': 'READING_LIST_NONE',
#      'allowResponses': True,
#      'statusForCollection': None,
#      'isPublished': True,
#      'clapCount': 1290,
#      'viewerClapCount': 0,
#      'pinnedAt': 0,
#      'pinnedByCreatorAt': 0,
#      'curationEligibleAt': 0,
#      'responseDistribution': 'NOT_DISTRIBUTED',
#      'shareKey': None,
#      'pendingCollection': None,
#      'voterCount': 489,
#      'recommenders': []},
#     'metadata': {'topic': None, '__typename': 'ExtendedFeedItemRankMetadata'},
#     '__typename': 'ExtendedFeedItem'},
#    {'post': {'id': '3cab1c76f1db',
#      'firstPublishedAt': 1613843042170,
#      'readingTime': 3.928301886792453,
#      'createdAt': 1613841073408,
#      'mediumUrl': 'https://medium.com/swlh/100x-your-money-with-this-cryptocurrency-3cab1c76f1db',
#      'previewImage': {'id': '0*fLQK8PiwhsVS7uZ6.jpg',
#       '__typename': 'ImageMetadata'},
#      'title': '100x Your Money With This Cryptocurrency',
#      'collection': {'id': 'f5af2b715248',
#       'domain': None,
#       'slug': 'swlh',
#       'name': 'The Startup',
#       'navItems': [{'url': 'https://medium.com/swlh/editors-picks/home',
#         '__typename': 'NavItem'},
#        {'url': 'https://medium.com/swlh/top-10-stories/home',
#         '__typename': 'NavItem'},
#        {'url': 'https://medium.com/swlh/start-it-up-submissions-3e8ed27bcd3e',
#         '__typename': 'NavItem'},
#        {'url': 'https://growthsupply.com/startupitup-newsletter/',
#         '__typename': 'NavItem'}],
#       'logo': {'id': '1*V-1gttEs5t-kNrGBeFGm7g.png',
#        '__typename': 'ImageMetadata'},
#       'avatar': {'id': '1*pKOfOAOvx-fWzfITATgGRg.jpeg',
#        '__typename': 'ImageMetadata'},
#       '__typename': 'Collection',
#       'viewerIsEditor': False,
#       'creator': {'id': 'd43c46db5b92', '__typename': 'User'},
#       'viewerIsMuting': False,
#       'isAuroraEligible': True,
#       'isAuroraVisible': False},
#      'creator': {'id': '8fd9c4e4744a',
#       'name': 'Angad Singh',
#       'username': 'angad17',
#       'imageId': '2*vlRfnr-Yxw1LhORJbvjKKg.jpeg',
#       'mediumMemberAt': 1559157496000,
#       '__typename': 'User',
#       'customDomainState': {'live': {'domain': 'angad17.medium.com',
#         '__typename': 'CustomDomain'},
#        '__typename': 'CustomDomainState'},
#       'hasSubdomain': True,
#       'isBlocking': None,
#       'isMuting': None,
#       'isAuroraVisible': True},
#      'visibility': 'LOCKED',
#      'isProxyPost': False,
#      'isLocked': True,
#      '__typename': 'Post',
#      'previewContent': {'subtitle': 'A hidden gem',
#       '__typename': 'PreviewContent',
#       'isFullContent': False},
#      'readingList': 'READING_LIST_NONE',
#      'allowResponses': True,
#      'statusForCollection': 'APPROVED',
#      'isPublished': True,
#      'clapCount': 1726,
#      'viewerClapCount': 0,
#      'pinnedAt': 0,
#      'pinnedByCreatorAt': 0,
#      'curationEligibleAt': 1613843041178,
#      'responseDistribution': 'NOT_DISTRIBUTED',
#      'shareKey': None,
#      'pendingCollection': None,
#      'voterCount': 368,
#      'recommenders': []},
#     'metadata': {'topic': None, '__typename': 'ExtendedFeedItemRankMetadata'},
#     '__typename': 'ExtendedFeedItem'},
#    {'post': {'id': 'ac8e5bc9b455',
#      'firstPublishedAt': 1615438897573,
#      'readingTime': 4.8669811320754715,
#      'createdAt': 1615269342451,
#      'mediumUrl': 'https://aninjusticemag.com/we-cant-afford-to-live-anymore-and-the-rich-are-gaslighting-us-ac8e5bc9b455',
#      'previewImage': {'id': '1*LDMv3nzRaYsgklB02Z0t8Q.jpeg',
#       '__typename': 'ImageMetadata'},
#      'title': 'We Can’t Afford to Live Anymore, and The Rich Are Gaslighting Us',
#      'collection': {'id': '998e693d29cd',
#       'domain': 'aninjusticemag.com',
#       'slug': 'an-injustice',
#       'name': 'An Injustice!',
#       'navItems': [{'url': 'https://aninjusticemag.com/fridaythings-stacyleekong/home',
#         '__typename': 'NavItem'},
#        {'url': 'https://aninjusticemag.com/kravitzm/home',
#         '__typename': 'NavItem'},
#        {'url': 'https://aninjusticemag.com/culture/home',
#         '__typename': 'NavItem'},
#        {'url': 'https://aninjusticemag.com/lgbtq/home',
#         '__typename': 'NavItem'},
#        {'url': 'https://aninjusticemag.com/women/home',
#         '__typename': 'NavItem'},
#        {'url': 'https://aninjusticemag.com/raceandpolitics/home',
#         '__typename': 'NavItem'},
#        {'url': 'https://aninjusticemag.com/write-for-us-b67daf126c25',
#         '__typename': 'NavItem'},
#        {'url': 'https://www.patreon.com/aninjusticemag',
#         '__typename': 'NavItem'}],
#       'logo': {'id': '1*vfCFF62zomv5379U7zcE0w.png',
#        '__typename': 'ImageMetadata'},
#       'avatar': {'id': '1*suDnvWWEvtqQCxA2NEHoRA.png',
#        '__typename': 'ImageMetadata'},
#       '__typename': 'Collection',
#       'viewerIsEditor': False,
#       'creator': {'id': 'c4c7f5e3de75', '__typename': 'User'},
#       'viewerIsMuting': False,
#       'isAuroraEligible': True,
#       'isAuroraVisible': False},
#      'creator': {'id': '8016b9f8ffc8',
#       'name': 'Jessica Wildfire',
#       'username': 'jessicalexicus',
#       'imageId': '1*WO6i2p_xtKnDvT2BUu5E7g.jpeg',
#       'mediumMemberAt': 1504339080000,
#       '__typename': 'User',
#       'customDomainState': {'live': {'domain': 'jessicalexicus.medium.com',
#         '__typename': 'CustomDomain'},
#        '__typename': 'CustomDomainState'},
#       'hasSubdomain': True,
#       'isBlocking': None,
#       'isMuting': None,
#       'isAuroraVisible': True},
#      'visibility': 'LOCKED',
#      'isProxyPost': False,
#      'isLocked': True,
#      '__typename': 'Post',
#      'previewContent': {'subtitle': 'It’s doing serious damage.',
#       '__typename': 'PreviewContent',
#       'isFullContent': False},
#      'readingList': 'READING_LIST_NONE',
#      'allowResponses': True,
#      'statusForCollection': 'APPROVED',
#      'isPublished': True,
#      'clapCount': 23934,
#      'viewerClapCount': 0,
#      'pinnedAt': 0,
#      'pinnedByCreatorAt': 0,
#      'curationEligibleAt': 1615438896838,
#      'responseDistribution': 'NOT_DISTRIBUTED',
#      'shareKey': None,
#      'pendingCollection': None,
#      'voterCount': 2575,
#      'recommenders': []},
#     'metadata': {'topic': None, '__typename': 'ExtendedFeedItemRankMetadata'},
#     '__typename': 'ExtendedFeedItem'},
#    {'post': {'id': '2ac516e4d8ad',
#      'firstPublishedAt': 1613720825294,
#      'readingTime': 2.750943396226415,
#      'createdAt': 1613703154474,
#      'mediumUrl': 'https://medium.com/the-shadow/i-started-using-noise-cancelling-headphone-this-is-what-happened-2ac516e4d8ad',
#      'previewImage': {'id': '1*2SHS_49Wzej7GimGHgD5Rg.jpeg',
#       '__typename': 'ImageMetadata'},
#      'title': 'I Started Using Noise-Cancelling Headphone—This Is What Happened',
#      'collection': {'id': '364b36074ee5',
#       'domain': None,
#       'slug': 'the-shadow',
#       'name': 'The Shadow',
#       'navItems': [{'url': 'https://medium.com/the-shadow/tips/home',
#         '__typename': 'NavItem'},
#        {'url': 'https://medium.com/the-shadow/latest/home',
#         '__typename': 'NavItem'},
#        {'url': 'https://medium.com/the-shadow/a-call-for-writers-a576f285aae5',
#         '__typename': 'NavItem'},
#        {'url': 'https://medium.com/the-shadow/about', '__typename': 'NavItem'},
#        {'url': 'https://www.patreon.com/theshadowpub',
#         '__typename': 'NavItem'}],
#       'logo': {'id': '1*zK4GsF4Lg6416H5P3Bg4zg.png',
#        '__typename': 'ImageMetadata'},
#       'avatar': {'id': '1*2i9or8s_gV6SNw9cHZg-2Q.png',
#        '__typename': 'ImageMetadata'},
#       '__typename': 'Collection',
#       'viewerIsEditor': False,
#       'creator': {'id': '74c166fc66c', '__typename': 'User'},
#       'viewerIsMuting': False,
#       'isAuroraEligible': False,
#       'isAuroraVisible': False},
#      'creator': {'id': '48f27255c1a8',
#       'name': 'Wonsuk Choi',
#       'username': 'wonsukwchoi',
#       'imageId': '1*33tmruGYXfLNr2Obafd6cw.jpeg',
#       'mediumMemberAt': 1582686062000,
#       '__typename': 'User',
#       'customDomainState': {'live': {'domain': 'wonsukwchoi.medium.com',
#         '__typename': 'CustomDomain'},
#        '__typename': 'CustomDomainState'},
#       'hasSubdomain': True,
#       'isBlocking': None,
#       'isMuting': None,
#       'isAuroraVisible': True},
#      'visibility': 'LOCKED',
#      'isProxyPost': False,
#      'isLocked': True,
#      '__typename': 'Post',
#      'previewContent': {'subtitle': 'I was never a headphone fan. I was satisfied with my Airpods until recently when I coworker talked about headphones. He was a…',
#       '__typename': 'PreviewContent',
#       'isFullContent': False},
#      'readingList': 'READING_LIST_NONE',
#      'allowResponses': True,
#      'statusForCollection': 'APPROVED',
#      'isPublished': True,
#      'clapCount': 1265,
#      'viewerClapCount': 0,
#      'pinnedAt': 0,
#      'pinnedByCreatorAt': 1615805959280,
#      'curationEligibleAt': 1613720841653,
#      'responseDistribution': 'NOT_DISTRIBUTED',
#      'shareKey': None,
#      'pendingCollection': None,
#      'voterCount': 271,
#      'recommenders': []},
#     'metadata': {'topic': None, '__typename': 'ExtendedFeedItemRankMetadata'},
#     '__typename': 'ExtendedFeedItem'},
#    {'post': {'id': '4848d8769eaa',
#      'firstPublishedAt': 1614807211050,
#      'readingTime': 8.01132075471698,
#      'createdAt': 1614708631168,
#      'mediumUrl': 'https://medium.com/mind-cafe/5-things-you-stop-doing-when-youre-finally-ready-to-change-your-life-4848d8769eaa',
#      'previewImage': {'id': '0*MUnQ3t97cFZ9gopZ',
#       '__typename': 'ImageMetadata'},
#      'title': '5 Things You Stop Doing When You’re Finally Ready to Change Your Life',
#      'collection': {'id': 'b5717b16a765',
#       'domain': None,
#       'slug': 'mind-cafe',
#       'name': 'Mind Cafe',
#       'navItems': [{'url': 'https://medium.com/mind-cafe/writing-for-mind-cafe-a5320ac4fa57',
#         '__typename': 'NavItem'},
#        {'url': 'https://medium.com/mind-cafe/our-purpose-at-mind-cafe-3ac38214e047',
#         '__typename': 'NavItem'},
#        {'url': 'https://medium.com/mind-cafe/1-to-1-writing-coaching-with-our-founder-adrian-drew-2150b1e3f3e2',
#         '__typename': 'NavItem'},
#        {'url': 'https://mindcafe.co/magazine', '__typename': 'NavItem'}],
#       'logo': {'id': '1*QI6Ea1mYV7zWQ96vNBcDoQ.png',
#        '__typename': 'ImageMetadata'},
#       'avatar': {'id': '1*8ndrLe4Ldljn8ba1A-FbFA.png',
#        '__typename': 'ImageMetadata'},
#       '__typename': 'Collection',
#       'viewerIsEditor': False,
#       'creator': {'id': 'd742ec3b7e2d', '__typename': 'User'},
#       'viewerIsMuting': False,
#       'isAuroraEligible': True,
#       'isAuroraVisible': False},
#      'creator': {'id': 'a66f89ac80ab',
#       'name': 'Ayodeji Awosika',
#       'username': 'chef-boyardeji',
#       'imageId': '2*YkbHaAA1eUYXY93CbGcATg.jpeg',
#       'mediumMemberAt': 1528700400000,
#       '__typename': 'User',
#       'customDomainState': {'live': {'domain': 'chef-boyardeji.medium.com',
#         '__typename': 'CustomDomain'},
#        '__typename': 'CustomDomainState'},
#       'hasSubdomain': True,
#       'isBlocking': None,
#       'isMuting': None,
#       'isAuroraVisible': True},
#      'visibility': 'LOCKED',
#      'isProxyPost': False,
#      'isLocked': True,
#      '__typename': 'Post',
#      'previewContent': {'subtitle': 'Even if you’ve spent a ton of time in your life making the wrong choices and failing to live up to your potential, there can come a day…',
#       '__typename': 'PreviewContent',
#       'isFullContent': False},
#      'readingList': 'READING_LIST_NONE',
#      'allowResponses': True,
#      'statusForCollection': 'APPROVED',
#      'isPublished': True,
#      'clapCount': 3650,
#      'viewerClapCount': 0,
#      'pinnedAt': 0,
#      'pinnedByCreatorAt': 0,
#      'curationEligibleAt': 1614708840217,
#      'responseDistribution': 'NOT_DISTRIBUTED',
#      'shareKey': None,
#      'pendingCollection': None,
#      'voterCount': 683,
#      'recommenders': []},
#     'metadata': {'topic': None, '__typename': 'ExtendedFeedItemRankMetadata'},
#     '__typename': 'ExtendedFeedItem'},
#    {'post': {'id': '8886a8b42715',
#      'firstPublishedAt': 1614953014756,
#      'readingTime': 3.0415094339622644,
#      'createdAt': 1614819144850,
#      'mediumUrl': 'https://medium.com/swlh/5-items-under-100-that-improved-my-productivity-8886a8b42715',
#      'previewImage': {'id': '1*Q5wSIh_hhU9Y2WUDt2Z9FA.jpeg',
#       '__typename': 'ImageMetadata'},
#      'title': '5 Items under $100 That Improved My Productivity',
#      'collection': {'id': 'f5af2b715248',
#       'domain': None,
#       'slug': 'swlh',
#       'name': 'The Startup',
#       'navItems': [{'url': 'https://medium.com/swlh/editors-picks/home',
#         '__typename': 'NavItem'},
#        {'url': 'https://medium.com/swlh/top-10-stories/home',
#         '__typename': 'NavItem'},
#        {'url': 'https://medium.com/swlh/start-it-up-submissions-3e8ed27bcd3e',
#         '__typename': 'NavItem'},
#        {'url': 'https://growthsupply.com/startupitup-newsletter/',
#         '__typename': 'NavItem'}],
#       'logo': {'id': '1*V-1gttEs5t-kNrGBeFGm7g.png',
#        '__typename': 'ImageMetadata'},
#       'avatar': {'id': '1*pKOfOAOvx-fWzfITATgGRg.jpeg',
#        '__typename': 'ImageMetadata'},
#       '__typename': 'Collection',
#       'viewerIsEditor': False,
#       'creator': {'id': 'd43c46db5b92', '__typename': 'User'},
#       'viewerIsMuting': False,
#       'isAuroraEligible': True,
#       'isAuroraVisible': False},
#      'creator': {'id': '1dec1a53f526',
#       'name': 'Matt Lillywhite',
#       'username': 'mattincanada',
#       'imageId': '1*ZUO1YbC_DbUkF6PLHFjyAw.jpeg',
#       'mediumMemberAt': 1555743600000,
#       '__typename': 'User',
#       'customDomainState': {'live': {'domain': 'mattincanada.medium.com',
#         '__typename': 'CustomDomain'},
#        '__typename': 'CustomDomainState'},
#       'hasSubdomain': True,
#       'isBlocking': None,
#       'isMuting': None,
#       'isAuroraVisible': True},
#      'visibility': 'LOCKED',
#      'isProxyPost': False,
#      'isLocked': True,
#      '__typename': 'Post',
#      'previewContent': {'subtitle': 'Because of them, it’s a lot easier to get my work done.',
#       '__typename': 'PreviewContent',
#       'isFullContent': False},
#      'readingList': 'READING_LIST_NONE',
#      'allowResponses': True,
#      'statusForCollection': 'APPROVED',
#      'isPublished': True,
#      'clapCount': 6092,
#      'viewerClapCount': 0,
#      'pinnedAt': 0,
#      'pinnedByCreatorAt': 0,
#      'curationEligibleAt': 1614953014040,
#      'responseDistribution': 'NOT_DISTRIBUTED',
#      'shareKey': None,
#      'pendingCollection': None,
#      'voterCount': 1543,
#      'recommenders': []},
#     'metadata': {'topic': None, '__typename': 'ExtendedFeedItemRankMetadata'},
#     '__typename': 'ExtendedFeedItem'},
#    {'post': {'id': '2358f8451ef9',
#      'firstPublishedAt': 1614009369069,
#      'readingTime': 3.29433962264151,
#      'createdAt': 1613669127384,
#      'mediumUrl': 'https://forge.medium.com/the-7-emails-you-should-send-every-week-to-get-ahead-in-your-career-2358f8451ef9',
#      'previewImage': {'id': '1*QsIbwFDqZ9IjpgMa-kJKug.jpeg',
#       '__typename': 'ImageMetadata'},
#      'title': 'The 7 Emails You Should Send Every Week to Get Ahead in Your Career',
#      'collection': {'id': '3f6ecf56618',
#       'domain': 'forge.medium.com',
#       'slug': 'forge',
#       'name': 'Forge',
#       'navItems': [],
#       'logo': {'id': '1*1cWFkPZeJn7fQREuNyHHOw.png',
#        '__typename': 'ImageMetadata'},
#       'avatar': {'id': '1*uWbn_ZpGom5xlrE-bX-EuQ.jpeg',
#        '__typename': 'ImageMetadata'},
#       '__typename': 'Collection',
#       'viewerIsEditor': False,
#       'creator': {'id': 'c626e36ed20', '__typename': 'User'},
#       'viewerIsMuting': False,
#       'isAuroraEligible': True,
#       'isAuroraVisible': True},
#      'creator': {'id': 'bb18b13c5ef4',
#       'name': 'Michael Thompson',
#       'username': 'michael-thompson',
#       'imageId': '1*Z883N6RmG0BqL6mw_gz4nA.png',
#       'mediumMemberAt': 1494260010000,
#       '__typename': 'User',
#       'customDomainState': {'live': {'domain': 'michael-thompson.medium.com',
#         '__typename': 'CustomDomain'},
#        '__typename': 'CustomDomainState'},
#       'hasSubdomain': True,
#       'isBlocking': None,
#       'isMuting': None,
#       'isAuroraVisible': True},
#      'visibility': 'LOCKED',
#      'isProxyPost': False,
#      'isLocked': True,
#      '__typename': 'Post',
#      'previewContent': {'subtitle': 'There’s power in the inbox',
#       '__typename': 'PreviewContent',
#       'isFullContent': False},
#      'readingList': 'READING_LIST_NONE',
#      'allowResponses': True,
#      'statusForCollection': 'APPROVED',
#      'isPublished': True,
#      'clapCount': 9288,
#      'viewerClapCount': 0,
#      'pinnedAt': 0,
#      'pinnedByCreatorAt': 0,
#      'curationEligibleAt': 1614009368577,
#      'responseDistribution': 'NOT_DISTRIBUTED',
#      'shareKey': None,
#      'pendingCollection': None,
#      'voterCount': 1981,
#      'recommenders': []},
#     'metadata': {'topic': None, '__typename': 'ExtendedFeedItemRankMetadata'},
#     '__typename': 'ExtendedFeedItem'},
#    {'post': {'id': '642172b959d2',
#      'firstPublishedAt': 1615551240101,
#      'readingTime': 4.592452830188679,
#      'createdAt': 1615547663183,
#      'mediumUrl': 'https://juliecohenauthor.medium.com/yes-it-is-all-men-642172b959d2',
#      'previewImage': {'id': '1*19_9_hO-vULr2qk7dfmldQ.jpeg',
#       '__typename': 'ImageMetadata'},
#      'title': 'Yes, it is all men.',
#      'collection': None,
#      'creator': {'id': 'ed470ed42b81',
#       'name': 'Julie Cohen',
#       'username': 'juliecohenauthor',
#       'imageId': '2*2Ach_9KJ_8O34uV1ORnotw.jpeg',
#       'mediumMemberAt': 0,
#       '__typename': 'User',
#       'customDomainState': {'live': {'domain': 'juliecohenauthor.medium.com',
#         '__typename': 'CustomDomain'},
#        '__typename': 'CustomDomainState'},
#       'hasSubdomain': True,
#       'isBlocking': None,
#       'isMuting': None,
#       'isAuroraVisible': True},
#      'visibility': 'LOCKED',
#      'isProxyPost': False,
#      'isLocked': True,
#      '__typename': 'Post',
#      'previewContent': {'subtitle': 'Even normal ones.',
#       '__typename': 'PreviewContent',
#       'isFullContent': False},
#      'readingList': 'READING_LIST_NONE',
#      'allowResponses': True,
#      'statusForCollection': None,
#      'isPublished': True,
#      'clapCount': 13905,
#      'viewerClapCount': 0,
#      'pinnedAt': 0,
#      'pinnedByCreatorAt': 0,
#      'curationEligibleAt': 1615551239302,
#      'responseDistribution': 'NOT_DISTRIBUTED',
#      'shareKey': None,
#      'pendingCollection': None,
#      'voterCount': 1283,
#      'recommenders': []},
#     'metadata': {'topic': None, '__typename': 'ExtendedFeedItemRankMetadata'},
#     '__typename': 'ExtendedFeedItem'},
#    {'post': {'id': '98baed2b4b7a',
#      'firstPublishedAt': 1614518727738,
#      'readingTime': 6.09433962264151,
#      'createdAt': 1613374418520,
#      'mediumUrl': 'https://medium.com/mind-cafe/7-habits-i-avoid-to-become-highly-productive-98baed2b4b7a',
#      'previewImage': {'id': '1*JgvK8XYmhPr8Hz3thMOx2A.jpeg',
#       '__typename': 'ImageMetadata'},
#      'title': '7 Habits I Avoid to Become Highly Productive',
#      'collection': {'id': 'b5717b16a765',
#       'domain': None,
#       'slug': 'mind-cafe',
#       'name': 'Mind Cafe',
#       'navItems': [{'url': 'https://medium.com/mind-cafe/writing-for-mind-cafe-a5320ac4fa57',
#         '__typename': 'NavItem'},
#        {'url': 'https://medium.com/mind-cafe/our-purpose-at-mind-cafe-3ac38214e047',
#         '__typename': 'NavItem'},
#        {'url': 'https://medium.com/mind-cafe/1-to-1-writing-coaching-with-our-founder-adrian-drew-2150b1e3f3e2',
#         '__typename': 'NavItem'},
#        {'url': 'https://mindcafe.co/magazine', '__typename': 'NavItem'}],
#       'logo': {'id': '1*QI6Ea1mYV7zWQ96vNBcDoQ.png',
#        '__typename': 'ImageMetadata'},
#       'avatar': {'id': '1*8ndrLe4Ldljn8ba1A-FbFA.png',
#        '__typename': 'ImageMetadata'},
#       '__typename': 'Collection',
#       'viewerIsEditor': False,
#       'creator': {'id': 'd742ec3b7e2d', '__typename': 'User'},
#       'viewerIsMuting': False,
#       'isAuroraEligible': True,
#       'isAuroraVisible': False},
#      'creator': {'id': '97afd8c17ab',
#       'name': 'Anthony J. Yeung',
#       'username': 'anthonyjyeung',
#       'imageId': '2*y2LK6q1ZCjTwhah9srttug.jpeg',
#       'mediumMemberAt': 1598965282000,
#       '__typename': 'User',
#       'customDomainState': {'live': {'domain': 'anthonyjyeung.medium.com',
#         '__typename': 'CustomDomain'},
#        '__typename': 'CustomDomainState'},
#       'hasSubdomain': True,
#       'isBlocking': None,
#       'isMuting': None,
#       'isAuroraVisible': True},
#      'visibility': 'LOCKED',
#      'isProxyPost': False,
#      'isLocked': True,
#      '__typename': 'Post',
#      'previewContent': {'subtitle': 'Cutting these things helped me boost my productivity.',
#       '__typename': 'PreviewContent',
#       'isFullContent': False},
#      'readingList': 'READING_LIST_NONE',
#      'allowResponses': True,
#      'statusForCollection': 'APPROVED',
#      'isPublished': True,
#      'clapCount': 10192,
#      'viewerClapCount': 0,
#      'pinnedAt': 0,
#      'pinnedByCreatorAt': 0,
#      'curationEligibleAt': 1614325962484,
#      'responseDistribution': 'NOT_DISTRIBUTED',
#      'shareKey': None,
#      'pendingCollection': None,
#      'voterCount': 2488,
#      'recommenders': []},
#     'metadata': {'topic': None, '__typename': 'ExtendedFeedItemRankMetadata'},
#     '__typename': 'ExtendedFeedItem'},
#    {'post': {'id': '8b592d50e530',
#      'firstPublishedAt': 1614783836587,
#      'readingTime': 14.545283018867924,
#      'createdAt': 1613811780526,
#      'mediumUrl': 'https://entrepreneurshandbook.co/the-exact-steps-i-followed-to-make-1-500-of-passive-income-every-month-8b592d50e530',
#      'previewImage': {'id': '1*OSRdL_JyKrpVsTTNIlFd9A.jpeg',
#       '__typename': 'ImageMetadata'},
#      'title': 'The  Exact Steps I Followed to Make $1,500+ of Passive Income Every Month',
#      'collection': {'id': '7adf33e44ae3',
#       'domain': 'entrepreneurshandbook.co',
#       'slug': 'entrepreneur-s-handbook',
#       'name': "Entrepreneur's Handbook",
#       'navItems': [{'url': 'https://entrepreneurshandbook.co/archive',
#         '__typename': 'NavItem'},
#        {'url': 'https://entrepreneurshandbook.co/write-for-entrepreneurs-handbook-7f9380ee9b63',
#         '__typename': 'NavItem'},
#        {'url': 'https://entrepreneurshandbook.co/im-looking-for-writers-8b16382fc089',
#         '__typename': 'NavItem'},
#        {'url': 'https://entrepreneurshandbook.co/entrepreneurs-handbook-audio-95827ee5edba',
#         '__typename': 'NavItem'},
#        {'url': 'https://entrepreneurshandbook.co/presenting-startup-summit-first-500-people-join-us-for-free-5ba25939e0ec',
#         '__typename': 'NavItem'},
#        {'url': 'https://entrepreneurshandbook.co/careershandbook/home',
#         '__typename': 'NavItem'},
#        {'url': 'https://mediumwritingcourse.com/', '__typename': 'NavItem'}],
#       'logo': {'id': '1*ac0J_hZgbf8DFOV76ysRsQ.png',
#        '__typename': 'ImageMetadata'},
#       'avatar': {'id': '1*ZpqTjur1EEzN4KzM4e-Bnw.png',
#        '__typename': 'ImageMetadata'},
#       '__typename': 'Collection',
#       'viewerIsEditor': False,
#       'creator': {'id': '540fcfc68d3a', '__typename': 'User'},
#       'viewerIsMuting': False,
#       'isAuroraEligible': False,
#       'isAuroraVisible': False},
#      'creator': {'id': 'c738f2120f50',
#       'name': 'Julia Horvath',
#       'username': 'juliahorvath',
#       'imageId': '1*P7TNzQ_eez2qllJm9w289A.jpeg',
#       'mediumMemberAt': 1565349812000,
#       '__typename': 'User',
#       'customDomainState': None,
#       'hasSubdomain': False,
#       'isBlocking': None,
#       'isMuting': None,
#       'isAuroraVisible': True},
#      'visibility': 'LOCKED',
#      'isProxyPost': False,
#      'isLocked': True,
#      '__typename': 'Post',
#      'previewContent': {'subtitle': 'I’m 29 and refuse to trade time for money. Here’s how you can do it too.',
#       '__typename': 'PreviewContent',
#       'isFullContent': False},
#      'readingList': 'READING_LIST_NONE',
#      'allowResponses': True,
#      'statusForCollection': 'APPROVED',
#      'isPublished': True,
#      'clapCount': 8899,
#      'viewerClapCount': 0,
#      'pinnedAt': 0,
#      'pinnedByCreatorAt': 1615288347754,
#      'curationEligibleAt': 1614615656478,
#      'responseDistribution': 'NOT_DISTRIBUTED',
#      'shareKey': None,
#      'pendingCollection': None,
#      'voterCount': 1566,
#      'recommenders': []},
#     'metadata': {'topic': None, '__typename': 'ExtendedFeedItemRankMetadata'},
#     '__typename': 'ExtendedFeedItem'}]}}

# %%
for r in result:
    print("Author: ", r["post"]['creator']["name"], "\nTitle: ",  r["post"]["title"], "\nSubtitle: ", r["post"]["previewContent"]["subtitle"])
# Out:
# Author:  Laura Vanderkam
# Title:  A Mental Trick to Make Any Task Less Intimidating
# Subtitle:  All you have to do is picture yourself on the other side
# Author:  umair haque
# Title:  How Britain Became the Dumbest Society in the World
# Subtitle:  Britain is Becoming the World’s Newest Failed State
# Author:  Shani Silver
# Title:  Please Be Cool With These Uncool Things Post-Pandemic
# Subtitle:  If you think you’re getting me back in zippy pants, you have another thing coming, good sir
# Author:  Lew C
# Title:  Flutter Is About To Win Over the Web
# Subtitle:  The cross-platform framework offers the most compelling web development experience
# Author:  Niklas Göke
# Title:  The Rule of 70/20/10
# Subtitle:  Do important work or none at all
# Author:  Sean Kernan
# Title:  Three Things in Life That Aren’t Worth The Effort
# Subtitle:  To be more efficient and happy, cut the waste and damaging activities from your life.
# Author:  Laura Vanderkam
# Title:  The Weekend Experiment That Will Change Your Life
# Subtitle:  You probably have more leisure time than you think. Here’s how to maximize it.
# Author:  Jason Ward
# Title:  North Korean 105-floor ‘Hotel of Doom’ Deserted for 30 Years
# Subtitle:  It’s a Guinness record holder for world’s tallest unoccupied building
# Author:  Bernie Bleske
# Title:  We Now Have a 4th Stage of Existence, and it may be the end of us all.
# Subtitle:  We need a new plan for the last 30 years of life.
# Author:  Rebecca Stevens A.
# Title:  How Does A Black Person Know If A White Person Is Racist?
# Subtitle:  We can tell within the first minute of meeting you
# Author:  Ravi Mistry
# Title:  The Future of Dashboards is Dashboardless
# Subtitle:  Earlier this year I wrote a long read about where I feel data visualisation is in 2021. In this post, I mention two things that I want to…
# Author:  Angad Singh
# Title:  100x Your Money With This Cryptocurrency
# Subtitle:  A hidden gem
# Author:  Jessica Wildfire
# Title:  We Can’t Afford to Live Anymore, and The Rich Are Gaslighting Us
# Subtitle:  It’s doing serious damage.
# Author:  Wonsuk Choi
# Title:  I Started Using Noise-Cancelling Headphone—This Is What Happened
# Subtitle:  I was never a headphone fan. I was satisfied with my Airpods until recently when I coworker talked about headphones. He was a…
# Author:  Ayodeji Awosika
# Title:  5 Things You Stop Doing When You’re Finally Ready to Change Your Life
# Subtitle:  Even if you’ve spent a ton of time in your life making the wrong choices and failing to live up to your potential, there can come a day…
# Author:  Matt Lillywhite
# Title:  5 Items under $100 That Improved My Productivity
# Subtitle:  Because of them, it’s a lot easier to get my work done.
# Author:  Michael Thompson
# Title:  The 7 Emails You Should Send Every Week to Get Ahead in Your Career
# Subtitle:  There’s power in the inbox
# Author:  Julie Cohen
# Title:  Yes, it is all men.
# Subtitle:  Even normal ones.
# Author:  Anthony J. Yeung
# Title:  7 Habits I Avoid to Become Highly Productive
# Subtitle:  Cutting these things helped me boost my productivity.
# Author:  Julia Horvath
# Title:  The  Exact Steps I Followed to Make $1,500+ of Passive Income Every Month
# Subtitle:  I’m 29 and refuse to trade time for money. Here’s how you can do it too.

# %% [markdown]
# ### Test zone

# %%
data = {'act': 'data-more', 'page': 2, 'eng': '30172'}

# %%
url = 'https://www.compel.ru/catalog/wireless/antenna'
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.90 Safari/537.36',
           'Referer': 'https://www.compel.ru/catalog/wireless/antenna'}

# %%
response1 = requests.post(url, headers=headers, data=data)

# %%
response = requests.get(url, headers=headers, data=data)

# %%
selector = etree.HTML(response.content.decode('utf8'))

# %%
datas = selector.xpath('//body[1]/div[2]/div[1]/div[1]/div[1]/div[1]/table[1]/tbody[1]')

# %%
for d in datas:
    pn = d.xpath('//tbody/tr[1]/td[1]/a[1]//text()')
    print(pn)

# %%
response.content.decode('utf8')
# Out:
# '<!DOCTYPE html> <html lang="ru"> <head itemscope itemtype="http://schema.org/WebSite"> <title>Антенны / Каталог</title>  <!-- Google Tag Manager -->  <script>(function (w, d, s, l, i) {  w[l] = w[l] || []; w[l].push({  \'gtm.start\': new Date().getTime(), event: \'gtm.js\' }); var f = d.getElementsByTagName(s)[0], j = d.createElement(s), dl = l != \'dataLayer\' ? \'&l=\' + l : \'\'; j.async = true; j.src = \'https://www.googletagmanager.com/gtm.js?id=\' + i + dl; f.parentNode.insertBefore(j, f); })(window, document, \'script\', \'dataLayer\', \'GTM-K5HTBW\');</script> <!-- End Google Tag Manager -->  <meta charset="utf-8"> <meta name="robots" content="index,follow"> <meta name="viewport" content="width=device-width, initial-scale=1.0"> <meta name="SKYPE_TOOLBAR" content="SKYPE_TOOLBAR_PARSER_COMPATIBLE"> <meta http-equiv="X-UA-Compatible" content="IE=edge">   <meta name="description" property="og:description" content="Антенны GSM, GPS, ГЛОНАСС, WiFi, ZigBee">        <!--[if lt IE 9]> <script src="/imgs/ie8/shivie8.min.js"></script> <script src="/imgs/ie8/es5-shim.min.js"></script> <script src="/imgs/ie8/es5-sham.min.js"></script> <link rel="stylesheet" href="/imgs/ie8/ie8.css"/> <![endif]-->  <link rel="icon" href="/favicon.ico" type="image/x-icon">  <link rel="search" href="/compel-osd.xml" type="application/opensearchdescription+xml" title="Компэл">  <link rel="canonical" href="/catalog/wireless/antenna">  <link rel="shortcut icon" href="/favicon.ico" type="image/x-icon"> <link rel="stylesheet" href="/assets/17.10.16.7/core.css">\r\n<link rel="stylesheet" href="/assets/17.10.16.7/www.css">\r\n<link rel="stylesheet" href="/assets/17.10.16.7/catalog.css">\r\n<meta name="fb:app_id" content="416364081848735">\r\n<meta name="og:locale" content="ru_RU"> </head>  <body itemscope itemtype="http://schema.org/WebPage" class="geo-zz geo-zz w-full-screen middle-2-col"  data-ver="17.10.16.7"  data-sys="www"  data-geo="ZZ"  data-usd="75.7576"  data-tpl="catalog-endpoint"  data-eng="30172"   >  <!-- Google Tag Manager (noscript) --> <noscript> <iframe src="https://www.googletagmanager.com/ns.html?id=GTM-K5HTBW" height="0" width="0" style="display:none;visibility:hidden"></iframe> </noscript> <!-- End Google Tag Manager (noscript) -->   <div id="hpb"></div>  <div class="middle">   <ul class="breadcrumbs" itemscope itemtype="http://schema.org/BreadcrumbList"> <li itemprop="itemListElement" itemscope itemtype="http://schema.org/ListItem" class="breadcrumb">\r\n<a href="/"\r\n   rel="home"\r\n   itemprop="item"\r\n   title="Главная"\r\n   class="breadcrumb-home">\r\n   <span itemprop="name">Главная</span>\r\n   <span class="tri tri-right"></span>\r\n   <meta itemprop="position" content="1" />\r\n</a>\r\n</li>\n<li itemprop="itemListElement" itemscope itemtype="http://schema.org/ListItem" class="breadcrumb">\r\n<a href="/catalog" title="Каталог продукции"\r\n   itemprop="item"\r\n   class="breadcrumb-link">\r\n   <span itemprop="name">Каталог</span>\r\n   <span class="tri tri-right"></span>\r\n   <meta itemprop="position" content="2" />\r\n</a>\r\n</li>\n<li itemprop="itemListElement" itemscope itemtype="http://schema.org/ListItem" class="breadcrumb">\r\n<a href="/catalog/wireless" \r\n   itemprop="item"\r\n   class="breadcrumb-link">\r\n   <span itemprop="name">Беспроводные технологии</span>\r\n   <span class="tri tri-right"></span>\r\n   <meta itemprop="position" content="3" />\r\n</a>\r\n</li> </ul>  <header class="site-header">  <div class="topheader"> <div class="site-logo user-logo"> <a href="/" title="Перейти на главную"> </a> </div> <!--noindex--> <div class="nw tr topheader-rightblock">  <site-search class="dib tm main-search-block pr"> <form itemscope itemprop="potentialAction" itemtype="http://schema.org/SearchAction" class="hide"> <meta itemprop="target" content="https://www.compel.ru/search?s={s}"> <input type="search" itemprop="query-input" name="s"> </form> </site-search>  <a href="/user/cart" class="dib header-cart a-block tr t ...

# %%
result = response1.content.decode('utf8')

# %%
x = json.loads(result)

# %%
x['_catalog_tbody']
# Out:
# '<tbody itemscope itemtype="http://schema.org/Product">\n<tr class="phash4crP4k1dhpyiGhTXj3IlnMC">\n<td class="tl tm item">   <a href="/infosheet/BEYOND/ANT%202.4%20BY-2400-01%20R%2FA%20RPSMA" itemprop="name"  class="item-link" target="_blank" title="Антенна - Монтаж: на разъём; Применение: индустриальное; Частоты: 2.4 ГГц; K усил: 2.14..." >ANT 2.4 BY-2400-01 R/A RPSMA (BEYOND)</a>    <div class="nw dib pn-actions"> <a class="j-copy-item i-fldr dib a-block" onclick="trigger(\'copyItem\', this)" data-pnid="ANT 2.4 BY-2400-01 R/A RPSMA (BEYOND)" title="Копировать" > </a><a class="j-cmpr i-cmpr dib a-block" title="Добавить к сравнению" target="_blank" >&nbsp;</a>   </div>   <br/> <i class="altpn" title="Альтернативное наименование">BY-2400-01 /Right angle, RPSMA/</i>    </td><td class="tc tm"><a href="/dataimg/beyond/pn/ant-2.4-by-2400-01-r-a-rpsma/76ae98aa693335e5281f1a58390917a4.jpg" target="_blank">\r\n    <img itemprop="image" src="data:image/png;base64,..." alt="Документация на ANT 2.4 BY-2400-01 R/A RPSMA" width="24" height="24" class="lightbox" />\r\n</a></td><td class="tc"><img src="data:image/gif;base64,..." class="ti" alt=""></td><td class="tc"><img src="data:image/gif;base64,..." class="ti" alt=""></td><td class="tr"><img src="data:image/gif;base64,..." class="ti" alt=""></td><td class="tr"><span style="color:silver" title="нет данных">&mdash;</span></td><td class="tc"><img src="data:image/gif;base64,..." class="ti" alt=""></td><td class="tr"><img src="data:image/gif;base64,..." class="ti" alt=""></td>\n</tr>\n</tbody><tbody itemscope itemtype="http://schema.org/Product">\n<tr class="phash1dAGiaKGIP410mQmW4TciBk">\n<td class="tl tm item">   <a href="/infosheet/BEYOND/ANT%202.4%20BY-2400-01%20SMA-M" itemprop="name"  class="item-link" target="_blank" title="Антенна - Монтаж: на разъём; Применение: индустриальное; Частоты: 2.4 ГГц; K усил: 3 dB..." >ANT 2.4 BY-2400-01 SMA-M (BEYOND)</a>    <div class="nw dib pn-actions"> <a class="j-copy-item i-fldr dib a-block" onclick="trigger(\'copyItem\', this)" data-pnid="ANT 2.4 BY-2400-01 SMA-M (BEYOND)" title="Копировать" > </a><a class="j-cmpr i-cmpr dib a-block" title="Добавить к сравнению" target="_blank" >&nbsp;</a>   </div>     </td><td class="tc tm"><a href="/dataimg/beyond/pn/ant-2.4-by-2400-01-sma-m/2a283d88e8e9fce7833d50bb69223ed0.jpg" target="_blank">\r\n    <img itemprop="image" src="data:image/png;base64,..." alt="Фотография ANT 2.4 BY-2400-01 SMA-M" width="24" height="24" class="lightbox" />\r\n</a></td><td class="tc"><img src="data:image/gif;base64,..." class="ti" alt=""></td><td class="tc"><img src="data:image/gif;base64,..." class="ti" alt=""></td><td class="tr"><img src="data:image/gif;base64,..." class="ti" alt=""></td><td class="tr"><span style="color:silver" title="нет данных">&mdash;</span></td><td class="tc"><img src="data:image/gif;base64,..." class="ti" alt=""></td><td class="tr"><img src="data:image/gif;base64,..." class="ti" alt=""></td>\n</tr>\n</tbody><tbody itemscope itemtype="http://schema.org/Product">\n<tr class="phash4JmNo34J1Tnj3yFMJ92YerwK">\n<td class="tl tm item">   <a href="/infosheet/BEYOND/ANT%202.4%20BY-2400-01-03%205cm%20RG178" itemprop="name"  class="item-link" target="_blank" title="Антенна - Применение: индустриальное; Частоты: 2.4 ГГц; K усил: 3 dBi; Разъём: нет; При..." >ANT 2.4 BY-2400-01-03 5cm RG178 (BEYOND)</a>    <div class="nw dib pn-actions"> <a class="j-copy-item i-fldr dib a-block" onclick="trigger(\'copyItem\', this)" data-pnid="ANT 2.4 BY-2400-01-03 5cm RG178 (BEYOND)" title="Копировать" > </a><a class="j-cmpr i-cmpr dib a-block" title="Добавить к сравнению" target="_blank" >&nbsp;</a>   </div>     </td><td class="tc tm"><a href="/dataimg/beyond/ps/by-2400-01-03/392344d2665b44805b3cbd605ac46223.jpg" target="_blank">\r\n    <img itemprop="image" src="data:image/png;base64,..." alt="Фотография серии BY-2400-01-03" width="24" height="24" class="lightbox" />\r\n</a></td><td class="tc"><img src="data:image/gif;base64,..." class ...

# %%
response.content.decode('utf8')
# Out:
# '<!DOCTYPE html> <html lang="ru"> <head itemscope itemtype="http://schema.org/WebSite"> <title>Антенны / Каталог</title>  <!-- Google Tag Manager -->  <script>(function (w, d, s, l, i) {  w[l] = w[l] || []; w[l].push({  \'gtm.start\': new Date().getTime(), event: \'gtm.js\' }); var f = d.getElementsByTagName(s)[0], j = d.createElement(s), dl = l != \'dataLayer\' ? \'&l=\' + l : \'\'; j.async = true; j.src = \'https://www.googletagmanager.com/gtm.js?id=\' + i + dl; f.parentNode.insertBefore(j, f); })(window, document, \'script\', \'dataLayer\', \'GTM-K5HTBW\');</script> <!-- End Google Tag Manager -->  <meta charset="utf-8"> <meta name="robots" content="index,follow"> <meta name="viewport" content="width=device-width, initial-scale=1.0"> <meta name="SKYPE_TOOLBAR" content="SKYPE_TOOLBAR_PARSER_COMPATIBLE"> <meta http-equiv="X-UA-Compatible" content="IE=edge">   <meta name="description" property="og:description" content="Антенны GSM, GPS, ГЛОНАСС, WiFi, ZigBee">        <!--[if lt IE 9]> <script src="/imgs/ie8/shivie8.min.js"></script> <script src="/imgs/ie8/es5-shim.min.js"></script> <script src="/imgs/ie8/es5-sham.min.js"></script> <link rel="stylesheet" href="/imgs/ie8/ie8.css"/> <![endif]-->  <link rel="icon" href="/favicon.ico" type="image/x-icon">  <link rel="search" href="/compel-osd.xml" type="application/opensearchdescription+xml" title="Компэл">  <link rel="canonical" href="/catalog/wireless/antenna">  <link rel="shortcut icon" href="/favicon.ico" type="image/x-icon"> <link rel="stylesheet" href="/assets/17.10.16.7/core.css">\r\n<link rel="stylesheet" href="/assets/17.10.16.7/www.css">\r\n<link rel="stylesheet" href="/assets/17.10.16.7/catalog.css">\r\n<meta name="fb:app_id" content="416364081848735">\r\n<meta name="og:locale" content="ru_RU"> </head>  <body itemscope itemtype="http://schema.org/WebPage" class="geo-zz geo-zz w-full-screen middle-2-col"  data-ver="17.10.16.7"  data-sys="www"  data-geo="ZZ"  data-usd="75.7576"  data-tpl="catalog-endpoint"  data-eng="30172"   >  <!-- Google Tag Manager (noscript) --> <noscript> <iframe src="https://www.googletagmanager.com/ns.html?id=GTM-K5HTBW" height="0" width="0" style="display:none;visibility:hidden"></iframe> </noscript> <!-- End Google Tag Manager (noscript) -->   <div id="hpb"></div>  <div class="middle">   <ul class="breadcrumbs" itemscope itemtype="http://schema.org/BreadcrumbList"> <li itemprop="itemListElement" itemscope itemtype="http://schema.org/ListItem" class="breadcrumb">\r\n<a href="/"\r\n   rel="home"\r\n   itemprop="item"\r\n   title="Главная"\r\n   class="breadcrumb-home">\r\n   <span itemprop="name">Главная</span>\r\n   <span class="tri tri-right"></span>\r\n   <meta itemprop="position" content="1" />\r\n</a>\r\n</li>\n<li itemprop="itemListElement" itemscope itemtype="http://schema.org/ListItem" class="breadcrumb">\r\n<a href="/catalog" title="Каталог продукции"\r\n   itemprop="item"\r\n   class="breadcrumb-link">\r\n   <span itemprop="name">Каталог</span>\r\n   <span class="tri tri-right"></span>\r\n   <meta itemprop="position" content="2" />\r\n</a>\r\n</li>\n<li itemprop="itemListElement" itemscope itemtype="http://schema.org/ListItem" class="breadcrumb">\r\n<a href="/catalog/wireless" \r\n   itemprop="item"\r\n   class="breadcrumb-link">\r\n   <span itemprop="name">Беспроводные технологии</span>\r\n   <span class="tri tri-right"></span>\r\n   <meta itemprop="position" content="3" />\r\n</a>\r\n</li> </ul>  <header class="site-header">  <div class="topheader"> <div class="site-logo user-logo"> <a href="/" title="Перейти на главную"> </a> </div> <!--noindex--> <div class="nw tr topheader-rightblock">  <site-search class="dib tm main-search-block pr"> <form itemscope itemprop="potentialAction" itemtype="http://schema.org/SearchAction" class="hide"> <meta itemprop="target" content="https://www.compel.ru/search?s={s}"> <input type="search" itemprop="query-input" name="s"> </form> </site-search>  <a href="/user/cart" class="dib header-cart a-block tr t ...
